# %%
import os
import pandas as pd
from pprint import pprint
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
gold_csv = "./resources/testing_dataset/lightfootcat/lightfootcat_9_mu_cleaned.csv"
eval_csv = "./outputs/lightfootcat_with_extract/lightfootcat_0.csv"

# %%
df_gold = pd.read_csv(gold_csv)
df_eval = pd.read_csv(eval_csv)

# %%
pprint(df_gold.columns)
pprint(df_eval.columns)
# Out:
# Index(['Unnamed: 0', 'division', 'family_name', 'species_name',
#        'number_of_folders', 'number_of_sheets', 'description'],
#       dtype='object')
# Index(['Unnamed: 0', 'division', 'family_name', 'species_name',
#        'number_of_folders', 'number_of_sheets', 'description',
#        'folders_and_sheets', 'species'],
#       dtype='object')

# %%
eval_columns = ['family_name', 'species_name','description']

# %%
len(df_gold["family_name"])
# Out:
# 1382

# %%
len(df_eval["family_name"])
# Out:
# 1404

# %%
import unicodedata, re
def clean(x, is_species=False):

    if pd.isna(x):
        return x
    x = unicodedata.normalize("NFKD", str(x)).strip().lower().replace("\\", "")
    if is_species:
        return " ".join(x.split(" ")[:3])
    return x

species_clean = lambda x: clean(x, is_species=True)
df_gold["family_name"] = df_gold["family_name"].map(clean)
df_gold["species_name"] = df_gold["species_name"].map(species_clean)
df_gold["description"] = df_gold["description"].map(clean)

df_eval["family_name"] = df_eval["family_name"].map(clean)
df_eval["species_name"] = df_eval["species_name"].map(species_clean)
df_eval["description"] = df_eval["description"].map(clean)

# %%
df_gold.head()
# Out:
#    Unnamed: 0       division    family_name            species_name  \
# 0           0  Dicotyledones      aceraceae       acer campestre l.
# 1           1  Dicotyledones      aceraceae  acer pseudoplatanus l.
# 2           2  Dicotyledones      aceraceae  acer pseudoplatanus l.
# 3           3  Dicotyledones  amaranthaceae  amaranthus lividus l.,
# 4           4  Dicotyledones     araliaceae         hedera helix l.
#
#    number_of_folders  number_of_sheets  \
# 0                1.0               0.0
# 1                2.0               0.0
# 2                2.0               0.0
# 3                1.0               0.0
# 4                1.0               0.0
#
#                                          description
# 0                        1 folder. acer campestre l.
# 1  folder 1. acer pseudo-platanus l. [g]. i. "map...
# 2                folder 2. acer pseudo-platanus [ta]
# 3                  1 folder. amaranthus blitum [ta].
# 4                        1 folder. hedera helix [ta]

# %%
" ".join(df_gold["species_name"][0].split(" ")[:3])
# Out:
# 'acer campestre l.'

# %% [markdown]
# #### Precision, Recall and F1
#
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)
#
# F1 = 2 x Precision x Recall / (Precision + Recall)
#
#
# ### Family
#
# Compare (family, species) pairs as a set
#
# ### Species Name
#
# Compare species occurences as a set

# %%
def eval(gold_set, eval_set):
    tp = len(gold_set & eval_set)
    fp = len(eval_set - gold_set)
    fn = len(gold_set - eval_set)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    return precision, recall, f1

# %%
species_gold = set(df_gold["species_name"].dropna().unique())
species_eval = set(df_eval["species_name"].dropna().unique())

sp_precision, sp_recall, sp_f1 = eval(species_gold, species_eval)
pprint(f"Species Name - Precision: {sp_precision:.4f}, Recall: {sp_recall:.4f}, F1 Score: {sp_f1:.4f}")
# Out:
# 'Species Name - Precision: 0.8751, Recall: 0.8741, F1 Score: 0.8746'

# %%
family_gold = set(tuple(x) for x in df_gold[["family_name", "species_name"]].dropna().values)
family_eval = set(tuple(x) for x in df_eval[["family_name", "species_name"]].dropna().values)
fam_precision, fam_recall, fam_f1 = eval(family_gold, family_eval)
pprint(f"Family Name - Precision: {fam_precision:.4f}, Recall: {fam_recall:.4f}, F1 Score: {fam_f1:.4f}")
# Out:
# 'Family Name - Precision: 0.8630, Recall: 0.8630, F1 Score: 0.8630'

# %%
df_gold.head()
# Out:
#    Unnamed: 0       division    family_name            species_name  \
# 0           0  Dicotyledones      aceraceae       acer campestre l.
# 1           1  Dicotyledones      aceraceae  acer pseudoplatanus l.
# 2           2  Dicotyledones      aceraceae  acer pseudoplatanus l.
# 3           3  Dicotyledones  amaranthaceae  amaranthus lividus l.,
# 4           4  Dicotyledones     araliaceae         hedera helix l.
#
#    number_of_folders  number_of_sheets  \
# 0                1.0               0.0
# 1                2.0               0.0
# 2                2.0               0.0
# 3                1.0               0.0
# 4                1.0               0.0
#
#                                          description
# 0                        1 folder. acer campestre l.
# 1  folder 1. acer pseudo-platanus l. [g]. i. "map...
# 2                folder 2. acer pseudo-platanus [ta]
# 3                  1 folder. amaranthus blitum [ta].
# 4                        1 folder. hedera helix [ta]

# %%
len(species_gold)
# Out:
# 882

# %%
len(species_eval)
# Out:
# 881

# %%
species_eval
# Out:
# {'acer campestre l.',
#  'acer pseudoplatanus l.',
#  'aceras anthropophorum (l.)',
#  'acinos arvensis (lam.)',
#  'actaea spicata l.',
#  'adonis annua l.',
#  'aegopodium podagraria l.',
#  'agrimonia eupatoria l.',
#  'agropyron caninum (l.)',
#  'agropyron junceiforme (a.&d.löve)',
#  'agropyron pungens (pers.)',
#  'agropyron repens (l.)',
#  'aira praecox l.',
#  'ajuga chamaepitys (l.)',
#  'ajuga reptans l.',
#  'alchemilla alpina l.',
#  'alchemilla glabra neygenfind',
#  'alchemilla vestita (buser)',
#  'alchemilla xanthochlora rothm.',
#  'alliaria petiolata (bieb.)',
#  'allium oleraceum l.',
#  'allium schoenoprasum l.',
#  'allium scorodoprasum l.',
#  'allium ursinum l.',
#  'althaea officinalis l.',
#  'amaranthus lividus l.,',
#  'ammophila arenaria (l.)',
#  'anacamptis pyramidalis (l.)',
#  'anagallis minima (l.)',
#  'anagallis monelli l.',
#  'anaphalis margaritacea (l.)',
#  'anemone nemorosa l.',
#  'antennaria dioica (l.)',
#  'antennaria neodioica greene',
#  'anthemis arvensis l.',
#  'anthemis cotula l.',
#  'anthoceros spp.',
#  'anthoxanthum odoratum l.',
#  'anthriscus caucalis bieb.',
#  'anthriscus cerefolium (l.)',
#  'anthriscus sylvestris (l.)',
#  'anthyllis vulneraria l.',
#  'antirrhinum orontium l.',
#  'apium graveolens',
#  'aquilegia alpina l.',
#  'aquilegia vulgaris l.',
#  'arabis hirsuta (l.)',
#  'arabis petraea (l.)',
#  'arabis sp.',
#  'arabis turrita l.',
#  'arenaria serpyllifolia l.',
#  'armeria maritima (mill.)',
#  'arnoseris minima (l.)',
#  'arrhenatherum elatius (l.)',
#  'artemisia absinthium l.',
#  'artemisia campestris l.',
#  'artemisia maritima l.',
#  'artemisia vulgaris l.',
#  'asarum europaeum l.',
#  'asparagus officinalis l.',
#  'asperula cynanchica l.',
#  'asplenium adiantum-nigrum l.',
#  'asplenium marinum l.',
#  'asplenium obovatum viv.',
#  'asplenium ruta-muraria l.',
#  'asplenium septentrionale (l.)',
#  'asplenium trichomanes l.',
#  'asplenium viride huds.',
#  'aster tripolium l.',
#  'astragalus danicus retz.',
#  'astragalus glycyphyllos l.',
#  'athyrium filix-femina (l.)',
#  'atriplex hastata l.',
#  'atriplex laciniata l.',
#  'atriplex littoralis l.',
#  'atriplex patula l.',
#  'avena fatua l.',
#  'avena fatua var.',
#  'avena nuda l.',
#  'avena sativa l.',
#  'avena strigosa schreb.',
#  'baldellia ranunculoides (l.)',
#  'ballota nigra l.',
#  'barbarea vulgaris r.br.',
#  'bartsia alpina l.',
#  'bellis perennis l.',
#  'berula erecta (huds.)',
#  'beta vulgaris l.',
#  'bidens cernua l.',
#  'blasia spp.',
#  'blechnum spicant (l.)',
#  'blysmus compressus (l.)',
#  'botrychium lunaria (l.)',
#  'brachypodium pinnatum (l.)',
#  'bractea membranacea',
#  'brassica napus l.',
#  'brassica nigra (l.)',
#  'brassica oleracea l.',
#  'briza media l.',
#  'briza minor l.,',
#  'bromus erectus huds.,',
#  'bromus ferronii mabille,',
#  'bromus madritensis l.,',
#  'bromus mollis l.,',
#  'bromus racemosus l.,',
#  'bromus secalinus l.,',
#  'bromus sterilis l.',
#  'bryonia dioica jacq.',
#  'bufonia tenuifolia l.,',
#  'butomus umbellatus l.',
#  'cakile maritima scop.',
#  'calamagrostis canescens (weber)',
#  'calamagrostis epigejos (l.)',
#  'calamintha ascendens jord.',
#  'calluna vulgaris (l.)',
#  'calluna vulgaris var',
#  'caltha palustris l.',
#  'camelina sativa (l.)',
#  'campanula latifolia l.',
#  'campanula patula l.',
#  'campanula rapunculus l.',
#  'campanula rotundifolia l.',
#  'campanula trachelium l.',
#  'capsella bursa-pastoris (l.)',
#  'cardamine amara l.',
#  'cardamine bellidifolia l.',
#  'cardamine hirsuta l.',
#  'cardamine impatiens l.',
#  'cardamine paratensis l.',
#  'cardamine umbellata greene,',
#  'carduus acanthoides l.',
#  'carduus crispus l.',
#  'carduus tenuiflorus curt.',
#  'carex acuta l.',
#  'carex acutiformis ehrh.',
#  'carex arenaria l.',
#  'carex atrata l.',
#  'carex binervis sm.',
#  'carex canescens lightfoot',
#  'carex capillaris l.',
#  'carex caryophyllea latour.',
#  'carex diandra schrank',
#  'carex digitata l.',
#  'carex dioica l.',
#  'carex distans l.',
#  'carex disticha huds.',
#  'carex divisa huds.',
#  'carex divulsa stokes',
#  'carex echinata murr.',
#  'carex extensa good.',
#  'carex flacca schreb.',
#  'carex flava l.',
#  'carex hostiana dc.',
#  'carex lasiocarpa ehrh.',
#  'carex limosa l.',
#  'carex maritima gunn.',
#  'carex nigra (l.)',
#  'carex ornithopoda willd.',
#  'carex otrubae podp.',
#  'carex ovalis good.',
#  'carex pallescens l.',
#  'carex panicea l.',
#  'carex paniculata l.',
#  'carex pauciflora lightfoot',
#  'carex pendula huds.',
#  'carex pilulifera l.',
#  'carex pseudocyperus l.',
#  'carex pulicaris l.',
#  'carex riparia curt.',
#  'carex rostrata stokes',
#  'carex spicata huds.',
#  'carex sylvatica huds.',
#  'carex vesicaria l.',
#  'carex vulpina l.',
#  'carex? lepidocarpa tausch',
#  'carex? rupestris all.',
#  'carex? saxatilis l.',
#  'carlina vulgaris l.',
#  'carum verticillatum (l.)',
#  'catabrosa aquatica (l.)',
#  'catapodium marinum (l.)',
#  'catapodium rigidum (l.)',
#  'centaurea cyanus l.',
#  'centaurea nigra l.',
#  'centaurea scabiosa l.',
#  'centaurea solstitialis l.',
#  'centaurium erythraea rafn',
#  'centaurium pulchellum (sw.)',
#  'centranthus ruber (l.)',
#  'cephalanthera longifolia (l.)',
#  'cerastium alpinum l.',
#  'cerastium arcticum lange',
#  'cerastium arvense l.',
#  'cerastium fontanum baumg.,',
#  'ceratophyllum demersum l.',
#  'ceterach officinarum dc.,',
#  'chaenorhinum minus (l.)',
#  'chaerophyllum temulentum l.',
#  'chamaemelum nobile (l.)',
#  'chamaenerion angustifolium (l.)',
#  'chamaepericlymenum suecicum (l.)',
#  'cheiranthus cheiri l.',
#  'chelidonium majus l.',
#  'chenopodium album l.',
#  'chenopodium bonus-henricus l.',
#  'chenopodium glaucum l.',
#  'chenopodium hybridum l.',
#  'chenopodium murale l.',
#  'chenopodium polyspermum l.',
#  'chenopodium rubrum l.',
#  'chenopodium vulvaria l.',
#  'chenopodium? suecicum j.murr.',
#  'chrysanthemum leucanthemum l.',
#  'chrysanthemum parthenium (l.)',
#  'chrysanthemum segetum l.',
#  'chrysanthemum vulgare (l.)',
#  'chrysosplenium alternifolium l.',
#  'cicendia filiformis (l.)',
#  'circaea alpina l.',
#  'circaea lutetiana l.',
#  'cirsium acaulon (l.)',
#  'cirsium dissectum (l.)',
#  'cirsium eriophorum (l.)',
#  'cirsium heterophyllum (l.)',
#  'cladium mariscus (l.)',
#  'clinopodium vulgare l.',
#  'cochlearia anglica l.',
#  'cochlearia danica l.',
#  'cochlearia groenlandica l.',
#  'cochlearia officinalis l.',
#  'coeloglossum viride (l.)',
#  'colchicum autumnale l.',
#  'conringia orientalis (l.)',
#  'convallaria majalis l.',
#  'conyza canadensis (l.)',
#  'corallorhiza trifida chatel',
#  'coriandrum sativum l.',
#  'coronopus squamatus (forsk.)',
#  'corydalis claviculata (l.)',
#  'corynephorus canescens (l.)',
#  'crassula tillaea lester-garland',
#  'crepis biennis l.',
#  'crepis capillaris (l.)',
#  'crepis foetida l.',
#  'crepis paludosa (l.)',
#  'crithum sp.',
#  'crocus sativus l.,',
#  'cryptogramma crispa (l.)',
#  'cucubalus baccifer l.',
#  'cynosurus cristatus l.',
#  'cynosurus echinatus l.',
#  'cyperus longus l.',
#  'cypripedium calceolus l.',
#  'cystopteris fragilis (l.)',
#  'damasonium alisma mill.',
#  'delphinium ambiguum l.',
#  'dentaria bulbifera l.',
#  'deschampsia caespitosa (l.)',
#  'deschampsia flexuosa (l.)',
#  'deschampsia setacea (huds.)',
#  'descurainia sophia (l.)',
#  'dianthus armeria l.',
#  'dianthus caryophyllus l.',
#  'dianthus deltoides l.',
#  'dianthus gratianopolitanus vill.',
#  'dipsacus pilosus l.',
#  'draba incana l.',
#  'draba muralis l.',
#  'drosera anglica huds.',
#  'drosera rotundifolia l.',
#  'dryas octopetala l.',
#  'dryopteris aemula (ait.)',
#  'dryopteris dilatata (hoffm.)',
#  'dryopteris filix-mas l.,',
#  'dryopteris spinulosa (mull.)',
#  'dryopteris villarsii (bell.)',
#  'elatine alsinastrum l.',
#  'eleocharis acicularis (l.)',
#  'eleocharis quinqueflora (f.x.hartm.)',
#  'eleogiton fluitans (l.)',
#  'elymus arenarius l.,',
#  'empetrum nigrum l.',
#  'endymion non-scriptus (l.)',
#  'epilobium anagallidifolium lam.',
#  'epilobium hirsutum l.',
#  'epilobium montanum l.',
#  'epilobium palustre l.',
#  'epilobium parviflorum schreb.',
#  'epilobium tetragonum l.',
#  'epipactis palustris (l.)',
#  'equisetum hyemale l.,',
#  'equisetum limosum l.,',
#  'equisetum palustre l.,',
#  'equisetum sylvaticum l.,',
#  'equisetum telmateja ehrh.,',
#  'erica cinerea l.',
#  'erica vagans l.',
#  'erigeron acer l.',
#  'eriocaulon septangulare with.',
#  'eriophorum angustifolium honck.',
#  'eriophorum vaginatum l.',
#  'erodium cicutarium (l.)',
#  'erodium maritimum (burm.',
#  'erodium moschatum (burm.',
#  'erophila verna (l.)',
#  'erysimum cheiranthoides l.',
#  'erysimum near helveticum',
#  'euonymus europaeus l.',
#  'euphorbia amygdaloides l.',
#  'euphorbia characias l.,',
#  'euphorbia exigua lin:',
#  'euphorbia hyberna l.',
#  'euphorbia paralias l.',
#  'euphorbia peplus l.',
#  'euphorbia platyphyllos l.',
#  'euphorbia portlandica l.',
#  'euphrasia brevipila burnat',
#  'fagopyrum esculentum moench.',
#  'festuca arundinacea schreb.,',
#  'festuca gigantea (l.)',
#  'festuca ovina l.,',
#  'festuca pratensis huds.,',
#  'festuca rubra l.',
#  'festuca rubra subsp.',
#  'festuca rubra var.',
#  'filago gallica l.',
#  'filago germanica l.',
#  'foeniculum vulgare mill.',
#  'fragaria vesca l.',
#  'frankenia laevis l.',
#  'frankenia pulverulenta l.,',
#  'fritillaria meleagris l.',
#  'fumaria officinalis l.',
#  'fumaria? bastardii boreau',
#  'gagea lutea (l.)',
#  'galanthus nivalis l.',
#  'galeopsis angustifolia ehrh.',
#  'galeopsis segetum neck.',
#  'galeopsis speciosa mill',
#  'galium boreale l.',
#  'galium cruciata (l.)',
#  'galium debile desv.',
#  'galium mollugo l.',
#  'galium odoratum (l.)',
#  'galium palustre l.',
#  'galium parisiense l.',
#  'galium pumilum murr.',
#  'galium tricornutum dandy',
#  'galium verum l.',
#  'genista anglica l.',
#  'genista pilosa l.',
#  'genista tinctoria l.',
#  'gentiana amarella (l.)',
#  'gentiana pneumonanthe l.',
#  'gentianella campestris (l.)',
#  'geranium columbinum l.',
#  'geranium dissectum l.',
#  'geranium lucidum l.',
#  'geranium phaeum l.',
#  'geranium pratense l.',
#  'geranium pusillum burm.',
#  'geranium pyrenaicum burm.',
#  'geranium rotundifolium l.',
#  'geranium sanguineum l.',
#  'geranium sylvaticum l.',
#  'geum rivale l.',
#  'geum urbanum l.',
#  'glaucium flavum crantz',
#  'glechoma hederacea l.',
#  'gnaphalium luteoalbum l.',
#  'gnaphalium supinum l.',
#  'gnaphalium sylvaticum l.',
#  'gnaphalium uliginosum l.',
#  'goodyera repens (l.)',
#  'gymnocarpium dryopteris (l.)',
#  'halimione pedunculata (l.)',
#  'halimione portulacoides (l.)',
#  'hedera helix l.',
#  'helianthemum apenninum (l.)',
#  'helianthemum canum (l.)',
#  'helianthemum chamaecistus mill',
#  'helictotrichon pratense (l.)',
#  'helictotrichon pubescens (huds.)',
#  'helleborus foetidus l.',
#  'helleborus viridis l.',
#  'herminium monorchis (l.)',
#  'herniaria ciliolata meld.',
#  'herniaria hirsuta l.',
#  'hesperis matronalis l.',
#  'hieracium alpinum l.',
#  'hieracium auricula [g].',
#  'hieracium lactucella wallr.',
#  'hieracium murorum agg.,',
#  'hieracium perproquinuum (zahn)',
#  'hieracium pilosella l.',
#  'hieracium umbellatum l.',
#  'himantoglossum hircinum (l.)',
#  'hippocrepis comosa l.',
#  'hippophae rhamnoides l.',
#  'hippuris vulgaris l.',
#  'holcus lanatus l.',
#  'holcus mollis l.',
#  'hordelymus europaeus (l.)',
#  'hordeum murinum l.',
#  'hordeum secalinum schreb.',
#  'hornungia petraea (l.)',
#  'hypericum androsaemum l.',
#  'hypericum elodes l.',
#  'hypericum humifusum l.',
#  'hypericum montanum l.',
#  'hypericum perforatum l.',
#  'hypericum sp.',
#  'hypochoeris glabra l.',
#  'hypochoeris maculata l.',
#  'hypochoeris radicata l.',
#  'iberis amara l.',
#  'illecebrum verticillatum l.',
#  'impatiens noli-tangere l.',
#  'inula conyza dc.',
#  'inula crithmoides l.',
#  'inula helenium l.',
#  'iris foetidissima l.',
#  'isatis tinctoria l.',
#  'isolepis setacea (l.)',
#  'jasione montana l.',
#  'juncus acutus l.',
#  'juncus articulatus l.',
#  'juncus biglumis l.',
#  'juncus bufonius l.',
#  'juncus bulbosus l.,',
#  'juncus filiformis l.',
#  'juncus gerardii lois.',
#  'juncus inflexus l.',
#  'juncus maritimus lam.',
#  'juncus sp.',
#  'juncus squarrosus l.',
#  'juncus trifidus l.',
#  'juncus triglumis l.',
#  'jungermannia spp.',
#  'kickxia spuria (l.)',
#  'knautia arvensis (l.)',
#  'koeleria cristata (l.)',
#  'koeleria vallesiana (honck.)',
#  'kohlräuschia prolifera (l.)',
#  'lactuca saligna l.',
#  'lactuca serriola l.',
#  'lactuca virosa l.',
#  'lamium album l.',
#  'lamium amplexicaule l.',
#  'lamium purpureum l.',
#  'lathyrus aphaca l.',
#  'lathyrus hirsutus l.',
#  'lathyrus japonicus willd.',
#  'lathyrus montanus bernh.',
#  'lathyrus nissolia l.',
#  'lathyrus palustris l.',
#  'lathyrus sylvestris l.',
#  'lavatera arborea l.',
#  'legousia hybrida (l.)',
#  'lemma trisulca l.',
#  'leontodon autumnalis l.',
#  'leontodon hispidus l.',
#  'leontodon taraxacoides (vill.)',
#  'leonurus cardiaca l.',
#  'lepidium campestre (l.)',
#  'lepidium latifolium l.',
#  'lepidium ruderale l.',
#  'leucorchis albida (l.)',
#  'ligusticum scoticum l.',
#  'limonium bellidifolium (gouan)',
#  'limonium binervosum (g.e.sm.)',
#  'limonium vulgare mill.',
#  'limosella aquatica l.',
#  'linaria arvensis agg.,',
#  'linaria repens (l.)',
#  'linnaea borealis l.',
#  'linum anglicum mill.',
#  'linum bienne mill.',
#  'linum perenne l.',
#  'littorella uniflora (l.)',
#  'lobelia dortmanna l.',
#  'lobelia urens l.',
#  'lolium multiflorum lam.,',
#  'lolium perenne l.,',
#  'lolium temulentum l.,',
#  'lonicera periclymenum l.',
#  'lotus corniculatus l.',
#  'lotus subbiflorus lag.',
#  'luronium natans (l.)',
#  'luzula campestris (l.)',
#  'luzula multiflora (retz.)',
#  'luzula spicata (l.)',
#  'luzula sylvatica (huds.)',
#  'lychnis coronaria (l.)',
#  'lychnis viscaria l.',
#  'lycopodium alpinum l.,',
#  'lycopodium annotinum l.,',
#  'lycopodium clavatum l.,',
#  'lycopodium selago l.,',
#  'lythrum hyssopifolia l.',
#  'lythrum salicaria l.',
#  'malva alcea l.',
#  'malva moschata l.',
#  'malva neglecta wallr.',
#  'marchantia spp.',
#  'marrubium vulgare l.',
#  'matricaria recutita l.',
#  'matthiola sinuata (l.)',
#  'meconopsis cambrica (l.)',
#  'medicago arabica (l.)',
#  'medicago falcata l.',
#  'medicago lupulina l.',
#  'medicago minima (l.)',
#  'medicago polymorpha l.',
#  'medicago sativa l.',
#  'melampyrum arvense l.',
#  'melampyrum cristatum l.',
#  'melampyrum sylvaticum l.',
#  'melica nutans l.,',
#  'melica uniflora retz.,',
#  'melilotus altissima thuill.',
#  'melittis melissophyllum l.',
#  'mentha aquatica l.',
#  'mentha arvensis l.',
#  'mentha rotundifolia (l.)',
#  'mentha × gentilis',
#  'mentha × niliaca',
#  'mentha × piperita',
#  'mentha × verticillata',
#  'mercurialis annua l.',
#  'minuartia hybrida (vill.)',
#  'minuartia sedoides (l.)',
#  'minuartia verna (l.)',
#  'moehringia trinervia (l.)',
#  'myosurus minimus l.',
#  'myrica gale l.',
#  'myriophyllum verticillatum l.',
#  'myrrhis odorata (l.)',
#  'narcissus majalis curt.',
#  'narcissus pseudonarcissus l.',
#  'narthecium ossifragum (l.)',
#  'neottia nidus-avis (l.)',
#  'nymphaea alba l.',
#  'odontites verna (bell.)',
#  'onobrychis viciifolia scop.',
#  'ononis repens l.',
#  'ononis spinosa l.',
#  'onopordum acanthium l.',
#  'ophioglossum vulgatum l.',
#  'ophrys apifera huds.',
#  'ophrys muscifera huds.',
#  'orchis simia lam.',
#  'orchis ustulata l.',
#  'origanum vulgare l.',
#  'ornithogalum umbellatum l.',
#  'ornithopus perpusillus l.',
#  'orthilia secunda (l.)',
#  'osmunda regalis l.',
#  'otanthus maritimus (l.)',
#  'oxalis acetosella l.',
#  'oxyria digyna (l.)',
#  'oxytropis halleri bunge',
#  'papaver argemone l.',
#  'papaver hybridum l.',
#  'parapholis strigosa (dumort.)',
#  'parentucellia viscosa (l.)',
#  'paris quadrifolia l.',
#  'parnassia palustris l.',
#  'pastinaca sativa l.',
#  'pedicularis palustris l.',
#  'pedicularis sylvatica l.',
#  'petasites hybridus (l.)',
#  'petroselinum segetum (l.)',
#  'peucedanum ostruthium (l.)',
#  'phragmites communis trin.,',
#  'phyllitis scolopendrium (l.)',
#  'phyteuma tenerum r.schulz',
#  'picris echioiodes l.',
#  'picris hieracioides l.',
#  'pimpinella major (l.)',
#  'pimpinella saxifraga l.',
#  'pinguicula alpina l.',
#  'pinguicula lusitanica l.',
#  'pinguicula vulgaris l.',
#  'pisum sativum l.',
#  'plantago coronopus l.',
#  'plantago lanceolata l.',
#  'plantago major l.',
#  'plantago maritima l.',
#  'plantago media l.',
#  'platanthera bifolia (l.)',
#  'platanthera? chlorantha (cust.)',
#  'poa alpina l.',
#  'poa angustifolia l.',
#  'poa annua l.',
#  'poa bulbosa l.',
#  'poa compressa l.',
#  'poa nemoralis l.',
#  'poa subcaerulea sm.',
#  'poa trivialis l.',
#  'polycarpon tetraphyllum (l.)',
#  'polygala vulgaris l.',
#  'polygonatum multiflorum (l.)',
#  'polygonatum odoratum (mill.)',
#  'polygonum amphibium l.',
#  'polygonum bistorta l.',
#  'polygonum convolvulus [ta]',
#  'polygonum hydropiper l.',
#  'polygonum minus huds.',
#  'polygonum persicaria l.',
#  'polygonum raii bab.',
#  'polygonum viviparum l.',
#  'polypodium vulgare l.,',
#  'polypodium vulgare var.',
#  'polystichum aculeatum (l.)',
#  'polystichum lonchitis (l.)',
#  'polystichum setiferum (forsk.)',
#  'potamogeton acutifolius link',
#  'potamogeton berchtoldii fieb.',
#  'potamogeton crispus l.',
#  'potamogeton obtusifolius mert.',
#  'potamogeton pectinatus l.',
#  'potamogeton perfoliatus l.',
#  'potamogeton polygonifolius pourr.',
#  'potamogeton pusillus l.',
#  'potamogeton trichoides cham.',
#  'potentilla alba l.,',
#  'potentilla anglica laicharding',
#  'potentilla argentea l.',
#  'potentilla erecta (l.)',
#  'potentilla fruticosa l.',
#  'potentilla palustris (l.)',
#  'potentilla reptans l.',
#  'potentilla rupestris l.',
#  'potentilla tabernaemontani aschers.',
#  'poterium sanguisorba l.',
#  'puccinellia distans (l.)',
#  'puccinellia fasciculata (torr.)',
#  'puccinellia maritima (huds.)',
#  'puccinellia rupestris (with.)',
#  'pulicaria dysenterica (l.)',
#  'pulicaria vulgaris gaertn.',
#  'pyrola minor l.',
#  'radiola linooides roth.',
#  'ranunculus arvensis l.',
#  'ranunculus auricomus l.',
#  'ranunculus bulbosus l.',
#  'ranunculus ficaria l.',
#  'ranunculus hederaceus l.',
#  'ranunculus lingua l.',
#  'ranunculus parviflorus l.',
#  'ranunculus repens l.',
#  'ranunculus sardous crantz',
#  'raphanus raphanistrum l.',
#  'reseda lutea l.',
#  'rhinathus? minor l.',
#  'rhynchospora alba (l.)',
#  'rhynchospora fusca (l.)',
#  'ribes alpinum l.',
#  'riccia spp.',
#  'rorippa islandica (oeder)',
#  'rorippa microphylla (boenn.',
#  'rorippa sylvestris (l.)',
#  'rosa arvensis huds.',
#  'rosa canina l.,',
#  'rosa canina var.',
#  'rosa rubiginosa l.',
#  'rosa villosa l.',
#  'rubia peregrina l.',
#  'rubus caesius l.',
#  'rubus chamaemorus l.',
#  'rubus idaeus l.',
#  'rubus saxatilis l.',
#  'rumex acetosella l.',
#  'rumex crispus l.',
#  'rumex maritimus l.',
#  'rumex sanguineus l.',
#  'rumex scutatus l.',
#  'ruppia maritima l.',
#  'sagina maritima g.don',
#  'sagina nodosa (l.)',
#  'sagina procumbens l.',
#  'sagina saginoides (l.)',
#  'sagina subulata (sw.)',
#  'salicornia europaea l.',
#  'salix alba l.',
#  'salix alba var.',
#  'salix arbuscula l.',
#  'salix aurita l.',
#  'salix caprea l.',
#  'salix cinerea l.',
#  'salix fragilis l.',
#  'salix fragilis var.',
#  'salix lapponum l.',
#  'salix myrsinites l.',
#  'salix pentandra l.',
#  'salix purpurea l.',
#  'salix repens l.',
#  'salix repens subsp.',
#  'salix reticulata l.',
#  'salix sp',
#  'salix sphacelata sm.,',
#  'salix triandra l.',
#  'salix viminalis l.',
#  'salix ×rubens schrank',
#  'salix ×rubra huds.',
#  'salsola kali l.',
#  'salvia pratensis l.',
#  'sambucus ebulus l.',
#  'samolus valerandi l.',
#  'sanguisorba officinalis l.',
#  'saponaria officinalis l.',
#  'sarothamnus scoparius (l.)',
#  'saussurea alpina (l.)',
#  'saxifraga aizoides l.',
#  'saxifraga cespitosa l.',
#  'saxifraga granulata l.',
#  'saxifraga hirculus l.',
#  'saxifraga hypnoides l.',
#  'saxifraga moschata wulf.,',
#  'saxifraga nivalis l.',
#  'saxifraga oppositifolia l.',
#  'saxifraga sp.',
#  'saxifraga stellaris l.',
#  'saxifraga virginiensis michx.,',
#  'schoenoplectus lacustris (l.)',
#  'schoenoplectus triquetrus (l.)',
#  'schoenus nigricans l.',
#  'scilla autumnalis l.',
#  'scirpus maritimus l.',
#  'scirpus sylvaticus l.',
#  'scleranthus annuus l.',
#  'scleranthus perennis l.',
#  'scrophularia nodosa l.',
#  'scrophularia scorodonia l.',
#  'scrophularia vernalis l.',
#  'scutellaria minor huds.',
#  'sedum acre l.',
#  'sedum album l.',
#  'sedum dasyphyllum l.',
#  'sedum forsteranum sm.',
#  'sedum rosea (l.)',
#  'sedum sexangulare l.',
#  'sedum telphium l.',
#  'sedum villosum l.',
#  'selaginella selaginoides (l.)',
#  'senecio abrotanifolius l.,',
#  'senecio fluviatilis wallr.',
#  'senecio integrifolius l.',
#  'senecio jacobaea l.',
#  'senecio sylvaticus l.',
#  'senecio viscosus l.',
#  'senecio vulgaris l.',
#  'serratula tinctoria l.',
#  'sesleria caerulea (l.)',
#  'sherardia arvensis l.',
#  'sibbaldia procumbens l.',
#  'sibthorpa europaea l.',
#  'sieglingia decumbens (l.)',
#  'silene acaulis (l.)',
#  'silene armeria l.',
#  'silene conoidea l.',
#  'silene dioica (l.)',
#  'silene gallica l.',
#  'silene italica (l.)',
#  'silene noctiflora l.',
#  'silene nutans l.',
#  'silene otites (l.)',
#  'silene vulgaris (moench)',
#  'silene vulgaris subsp.',
#  'silybum marianum (l.)',
#  'sinapis alba l.',
#  'sinapis arvensis l.',
#  'sisum amomum l.',
#  'sisymbrium irio l.',
#  'sisymbrium officinale (l.)',
#  'sium latifolium l.',
#  'smyrnium olusatum l.',
#  'solidago virgaurea l.',
#  'sonchus arvensis l.',
#  'sparganium erectum l.',
#  'sparganium minimum wallr.',
#  'spergula arvensis l.',
#  'spergularia media (l.)',
#  'spergularia sp.',
#  'spiranthes spiralis (l.)',
#  'stachys arvensis (l.)',
#  'stachys palustris l.',
#  'staphylea pinnata l.',
#  'stellaria alcine grimm',
#  'stellaria holostea l.',
#  'stellaria nemorum l.',
#  'stipa pennata l.,',
#  'stratiotes aloides l.',
#  'suaeda fruticosa forsk.',
#  'suaeda maritima (l.)',
#  'swertia perennis l.,',
#  'taraxacum officinale weber,',
#  'teesdalia nudicaulis (l.)',
#  'teucrium scordium l.',
#  'teucrium scorodonia l.',
#  'thalictrum alpinum l.',
#  'thalictrum minus l.',
#  'thelycrania sericea (l.)',
#  'thelypteris oreopteris (ehrh.)',
#  'thelypteris palustris schott',
#  'thelypteris phegopteris (l.)',
#  'thesium humifusum dc.',
#  'thlaspi alpestre l.',
#  'thlaspi arvense l.',
#  'thlaspi perfoliatum l.',
#  'tilia cordata mill.',
#  'tragopogon porrifolius l.',
#  'trichophorum cespitosum (l.)',
#  'trientalis europaea l.',
#  'trifolium arvense l.',
#  'trifolium campestre schreb.',
#  'trifolium dubium sibth.',
#  'trifolium fragiferum l.',
#  'trifolium glomeratum l.',
#  'trifolium medium l.',
#  'trifolium ochroleucon huds.',
#  'trifolium ornithopodioides l.',
#  'trifolium pratense l.',
#  'trifolium repens l.',
#  'trifolium scabrum l.',
#  'trifolium squamosum l.',
#  'trifolium striatum l.',
#  'trifolium subterranean l.',
#  'triglochin maritima l.',
#  'triglochin palustris l.',
#  'trinia glauca (l.)',
#  'triplemospermum maritimum (l.)',
#  'trisetum flavescens (l.)',
#  'trollius europaeus l.',
#  'tuberaria guttata (l.)',
#  'turritis glabra l.',
#  'tussilago farfara l.',
#  'typha angustifolia l.',
#  'ulex europaeus l.',
#  'ulmus glabra huds.',
#  'ulmus procera salisb.',
#  'umbilicus rupestris (salisb.)',
#  'urtica pilulifera l.',
#  'vaccinium myrtillus l.',
#  'vaccinium ovalifolium sm.',
#  'vaccinium oxycoccus l.',
#  'veronica alpina l.',
#  'veronica beccabunga l.',
#  'veronica hederifolia l.',
#  'veronica montana l.',
#  'veronica officinalis l.',
#  'veronica scutellata l.',
#  'veronica serpyllifolia l.',
#  'veronica spicata l.',
#  'veronica triphyllos l.',
#  'viburnum lantana l.',
#  'viburnum opulus l.',
#  'vicia cracca l.',
#  'vicia hirsuta (l.)',
#  'vicia lathyroides l.',
#  'vicia lutea l.',
#  'vicia orobus dc.',
#  'vicia sativa l.',
#  'vicia sepium l.',
#  'vicia sylvatica l.',
#  'vicia tetrasperma (l.)',
#  'viola hirta l.',
#  'viola lutea huds.',
#  'viola riviniana rchb.',
#  'viola spp.',
#  'viola tricolor l.',
#  'vulpia bromoides (l.)',
#  'vulpia membranacea (l.)',
#  'vulpia myuros (l.)',
#  'wahlenbergia hederacea (l.)',
#  'woodsia ilvensis r.br.',
#  'zannichellia palustris l.',
#  'zostera angustifolia (hornem.)',
#  'zostera marina l.',
#  '× festulolium loliaceum'}

# %%
species_gold
# Out:
# {'acer campestre l.',
#  'acer pseudoplatanus l.',
#  'aceras anthropophorum (l.)',
#  'acinos arvensis (lam.)',
#  'actaea spicata l.',
#  'adonis annua l.',
#  'aegopodium podagraria l.',
#  'agrimonia eupatoria l.',
#  'agropyron caninum (l.)',
#  'agropyron junctiforme -',
#  'agropyron pungens (pers.)',
#  'agropyron repens (l.)',
#  'aira praecox l.',
#  'ajuga chamaepitys (l.)',
#  'ajuga reptans l.',
#  'alchemilla alpina l.',
#  'alchemilla glabra neygenfind',
#  'alchemilla vestita (buser)',
#  'alchemilla xanthochlora rothm.',
#  'alliaria petiolata (bieb.)',
#  'allium oleraceum l.',
#  'allium schoenoprasum l.',
#  'allium scorodoprasum l.',
#  'allium ursinum l.',
#  'alnus glutinosa (l.)',
#  'althaea officinalis l.',
#  'amaranthus lividus l.,',
#  'ammophila arenaria (l.)',
#  'amostris minima (l.)',
#  'anacamptis pyramidalis (l.)',
#  'anagallis minima (l.)',
#  'anagallis monelli l.',
#  'anaphalis margaritacea (l.)',
#  'anemone nemorosa l.',
#  'antennaria dioica (l.)',
#  'anthemis arvensis l.',
#  'anthemis cotula l.',
#  'anthoceros spp.',
#  'anthoxanthum odoratum l.',
#  'anthriscus caucalis bieb.',
#  'anthriscus cerefolium (l.)',
#  'anthriscus sylvestris (l.)',
#  'anthyllis vulneraria l.',
#  'antirrhinum orontium l.',
#  'apium graveolens',
#  'aquilegia alpina l.',
#  'aquilegia vulgaris l.',
#  'arabis hirsuta (l.)',
#  'arabis petraea (l.)',
#  'arabis sp.',
#  'arabis turrita l.',
#  'arenaria serpyllifolia l.',
#  'armeria maritima (mill.)',
#  'arrhenatherum elatius (l)',
#  'artemisia absinthium l.',
#  'artemisia campestris l.',
#  'artemisia maritima l.',
#  'artemisia vulgaris l.',
#  'asarum europaeum l.',
#  'asparagus officinalis l.',
#  'asperula cynanchica l.',
#  'asplenium adiantum-nigrum l.,',
#  'asplenium marinum l.,',
#  'asplenium obovatum viv.,',
#  'asplenium ruta-muraria l.,',
#  'asplenium septentrionale (l.)',
#  'asplenium trichomanes l.,',
#  'asplenium viride huds.,',
#  'aster tripolium l.',
#  'astragalus danicus retz.',
#  'astragalus glycyphyllos l.',
#  'athyrium filix-femina (l.)',
#  'atriplex hastata l.',
#  'atriplex laciniata l.',
#  'atriplex littoralis l.',
#  'atriplex patula l.',
#  'atriplex sylvestris polygoni',
#  'avena fatua l.',
#  'avena fatua var.',
#  'avena nuda l.',
#  'avena sativa l.',
#  'avena strigosa schreb.',
#  'baldellia ranunculoides (l.)',
#  'ballota nigra l.',
#  'barbara vulgaris r.br.',
#  'bartsia alpina l.',
#  'bellis perennis l.',
#  'berula erecta (huds.)',
#  'beta vulgaris l.',
#  'betula nana l.',
#  'bidens cernua l.',
#  'blackstonia perfoliata (l.)',
#  'blasia spp.',
#  'blechnum spicant (l.)',
#  'blysmus compressus (l.)',
#  'botrychium lunaria (l.)',
#  'brachypodium pinnatum (l.)',
#  'brachypodium sylvaticum (huds.)',
#  'bractea membranacea',
#  'brassica napus l.',
#  'brassica nigra (l.)',
#  'brassica oleracea l.',
#  'briza media l.,',
#  'briza minor l.,',
#  'bromus erectus huds.,',
#  'bromus ferronii mabille,',
#  'bromus madritensis huds.',
#  'bromus madritensis l.,',
#  'bromus mollis l.,',
#  'bromus pinnatus lin:',
#  'bromus racemosus l.,',
#  'bromus secalinus l.,',
#  'bromus sterilis l.,',
#  'bryonia dioica jacq.',
#  'bufonia tenuifolia l.',
#  'butomus umbellatus l.',
#  'cakile maritima scop.',
#  'calamagrostis - epigeos',
#  'calamagrostis canescens (weber)',
#  'calamintha ascendens jord.',
#  'calluna vulgaris (l.)',
#  'calluna vulgaris var',
#  'caltha palustris l.',
#  'camelina sativa (l.)',
#  'campanula latifolia l.',
#  'campanula patula l.',
#  'campanula rapunculus l.',
#  'campanula rotundifolia l.',
#  'campanula trachelium l.',
#  'capsella bursa-pastoris (l.)',
#  'cardamine amara l.',
#  'cardamine bellidifolia l.',
#  'cardamine hirsuta l.',
#  'cardamine impatiens l.',
#  'cardamine pratensis l..',
#  'cardamine umbellata greene,',
#  'carduus acanthoides l.',
#  'carduus crispus l.',
#  'carduus tenuiflorus curt.',
#  'carex acuta l..',
#  'carex acutiformis ehrh.',
#  'carex arenaria l.',
#  'carex atrata l.',
#  'carex binervis sm.',
#  'carex capillaris l.',
#  'carex caryophylla latour.',
#  'carex curta good.',
#  'carex diandra schrank',
#  'carex digitata l.',
#  'carex dioica l.',
#  'carex distans l.',
#  'carex disticha huds.',
#  'carex divisa huds.',
#  'carex divulsa stokes',
#  'carex echinata murr.',
#  'carex extensa good.',
#  'carex flacca schreb.',
#  'carex flava l.',
#  'carex flava?',
#  'carex hostiana dc..',
#  'carex lasiocarpa ehrh.',
#  'carex lepidocarpa tausch',
#  'carex limosa l.',
#  'carex maritima gunn.',
#  'carex nigra (l.)',
#  'carex nova?',
#  'carex ornithopoda willd.',
#  'carex otrubae podp.',
#  'carex ovalis good.',
#  'carex pallescens',
#  'carex pallescens l.',
#  'carex panicea l.',
#  'carex paniculata l.',
#  'carex paniculata var.',
#  'carex pauciflora lightfoot',
#  'carex pendula huds..',
#  'carex pilulifera l.',
#  'carex pseudocyperus l.',
#  'carex pulicaris l.',
#  'carex riparia curt.',
#  'carex rostrata stokes',
#  'carex spicata huds.',
#  'carex sylvatica huds.',
#  'carex vesicaria l.',
#  'carex vulpina l.',
#  'carex? rupestris all.',
#  'carex? saxatilis l.',
#  'carlina vulgaris l.',
#  'carum verticillatum (l.)',
#  'catabrosa aquatica (l.)',
#  'catapodium marinum (l.)',
#  'catapodium rigidum (l.)',
#  'centaurea cyanus l.',
#  'centaurea nigra l.',
#  'centaurea solstitialis l.',
#  'centaurium erythraea rafn',
#  'centaurium pulchellum (sw.)',
#  'centranthus ruber (l.)',
#  'cephalanthera longifolia (l.)',
#  'cerastium alpinum l.',
#  'cerastium arcticum lange',
#  'cerastium arvense l.',
#  'cerastium fontanum baumg.',
#  'ceratophyllum demersum l.',
#  'ceterach officinarum dc.,',
#  'chaenorhinum minus (l.)',
#  'chaerophyllum temulentum l.',
#  'chamaemelum nobile (l.)',
#  'chamaenerion angustifolium (l.)',
#  'chamaepericlymenum suecicum (l.)',
#  'chara spp.',
#  'cheiranthus cheiri l.',
#  'chelidonium majus l.',
#  'chenopodium album l.',
#  'chenopodium bonus-henricus l.',
#  'chenopodium glaucum l.',
#  'chenopodium hybridum l.',
#  'chenopodium murale l.',
#  'chenopodium polyspermum l.',
#  'chenopodium rubrum l.',
#  'chenopodium vulvaria l..',
#  'chenopodium? suecicum j.',
#  'chrysanthemum leucanthemum l.',
#  'chrysanthemum parthenium (l.)',
#  'chrysanthemum segetum l.',
#  'chrysanthemum vulgare (l.)',
#  'chrysosplenium alternifolium l.',
#  'cicendia filiformis (l.)',
#  'circaea alpina l.',
#  'circaea lutetiana l.',
#  'cirsium acaulon (l.)',
#  'cirsium dissectum (l.)',
#  'cirsium eriophorum (l.)',
#  'cirsium heterophyllum (l.)',
#  'cladium mariscus (l.)',
#  'clinopodium vulgare l.',
#  'cochlearia anglica l.',
#  'cochlearia danica l.',
#  'cochlearia groenlandica l.',
#  'cochlearia officinalis l.',
#  'coeloglossum viride (l.)',
#  'colchicum autumnale l.',
#  'conringia orientalis (l.)',
#  'convallaria majalis l.',
#  'conyza canadensis (l.)',
#  'corallorhiza trifida chatel',
#  'coriandrum sativum l.',
#  'coronopus squamatus (forsk.)',
#  'corydalis claviculata (l.)',
#  'corynephorus canescens (l.)',
#  'crassula tillaea lester-garland',
#  'crepis biennis l.',
#  'crepis foetida l.',
#  'crepis paludosa (l.)',
#  'crithmum sp.',
#  'crocus sativus l.,',
#  'cryptogramma crispa (l.)',
#  'cucubalus baccifer l.',
#  'cynosurus cristatus l.,',
#  'cynosurus echinatus l.,',
#  'cyperus longus l.',
#  'cypripedium calceolus l.',
#  'cystopteris fragilis (l.)',
#  'damasonium alisma mill.',
#  'delphinium ambiguum l.',
#  'dentaria bulbifera l.',
#  'deschampsia caespitosa (l.)',
#  'deschampsia flexuosa (l.)',
#  'deschampsia setacea (huds.)',
#  'descurainia sophia (l.)',
#  'dianthus arenarius huds.',
#  'dianthus armeria l.',
#  'dianthus caryophyllus l.',
#  'dianthus deltoides l.',
#  'dianthus gratianopolitanus vill.',
#  'dipsacus pilosus l.',
#  'draba incana l.',
#  'draba muralis l.',
#  'drosera anglica huds.',
#  'drosera rotundifolia l.',
#  'dryas octopetala l.',
#  'dryopteris aemula (ait.)',
#  'dryopteris dilatata (hoffm.)',
#  'dryopteris spinulosa (mull)',
#  'dryopteris villarsii (bell.)',
#  'elatine alsinastrum l.,',
#  'eleocharis acicularis (l.)',
#  'eleocharis quinqueflora (e.x.hartm.)',
#  'eleogiton fluitans (l.)',
#  'elymus arenarius l.,',
#  'empetrum nigrum l.',
#  'endymion non-scriptus (l.)',
#  'epilobium anagallidifolium lam.',
#  'epilobium hirsutum l.',
#  'epilobium montanum l.',
#  'epilobium palustre l.',
#  'epilobium parviflorum schreb.',
#  'epilobium tetragonum l.',
#  'epipactis palustris (l.)',
#  'equisetum hyemale l.',
#  'equisetum limosum l.',
#  'equisetum palustre l.',
#  'equisetum sylvaticum l.',
#  'equisetum telmateja ehrh.',
#  'erica cinerea l.',
#  'erica vagans l.',
#  'erigeron acer l.',
#  'eriocaulon septangulare with.',
#  'eriophorum angustifolium honck.',
#  'eriophorum vaginatum l.',
#  'erodium cicutarium (l.)',
#  'erodium maritimum (burm.',
#  'erodium moschatum (burm.',
#  'erophila verna (l.)',
#  'erysimum cheiranthoides l.',
#  'erysimum near helveticum',
#  'euonymus europaeus l.',
#  'euphorbia amygdaloides l.',
#  'euphorbia characias l.',
#  'euphorbia exigua l.',
#  'euphorbia hyberna l.',
#  'euphorbia paralias l.',
#  'euphorbia peplus l.',
#  'euphorbia platyphyllos l.',
#  'euphorbia portlandica l.',
#  'euphrasia brevipila burnat',
#  'fagopyrum esculentum moench.',
#  'festuca arundinacea schreb.,',
#  'festuca gigantea (l.)',
#  'festuca loliaceaum (huds.)',
#  'festuca ovina l.,',
#  'festuca pratensis huds.,',
#  'festuca rubra l.',
#  'festuca rubra subsp.',
#  'festuca rubra var.',
#  'festuca sylvatica huds.:',
#  'filago gallica l.',
#  'filago germanica l.',
#  'flosculi distantes; infra,',
#  'foeniculum vulgare mill.',
#  'fragaria vesca l.',
#  'frankenia laevis l.',
#  'frankenia pulverulenta l.,',
#  'fritillaria meleagris l.',
#  'fumaria officinalis l.',
#  'gagea lutea (l.)',
#  'galanthus nivalis l.',
#  'galeopsis angustifolia ehrh.',
#  'galeopsis segetum neck.',
#  'galeopsis speciosa mill',
#  'galium boreale l.',
#  'galium cruciata (l.)',
#  'galium debile desv.',
#  'galium mollugo l.',
#  'galium odoratum (l.)',
#  'galium palustre l.',
#  'galium parisiense l.',
#  'galium pumilum murr.',
#  'galium tricornutum dandy.',
#  'genista anglica l.',
#  'genista pilosa l.',
#  'genista tinctoria l.',
#  'gentiana amarella (l.)',
#  'gentiana pneumonanthe l.',
#  'gentianella campestris (l.)',
#  'geranium columbinum l.',
#  'geranium dissectum l.',
#  'geranium lucidum l.',
#  'geranium phaeum l.',
#  'geranium pratense l.',
#  'geranium pusillum burm.',
#  'geranium pyrenaicum burm.',
#  'geranium rotundifolium l.',
#  'geranium sanguineum l.',
#  'geranium sylvaticum l.',
#  'geum rivale l.',
#  'geum urbanum l.',
#  'glaucium flavum crantz',
#  'glechoma hederacea l.',
#  'gnaphalium luteoalbum l.',
#  'gnaphalium supinum l.',
#  'gnaphalium sylvaticum l.',
#  'gnaphalium uliginosum l.',
#  'goodyera repens (l.)',
#  'gymnocarpium dryopteris (l.)',
#  'halimione pedunculata (l.)',
#  'halimione portulacoides (l..)',
#  'hedera helix l.',
#  'helianthemum apenninum (l.)',
#  'helianthemum canum (l.)',
#  'helianthemum chamaecistus mill',
#  'helictotrichon pratense (l.)',
#  'helictotrichon pubescens (huds.)',
#  'helleborus foetidus l.',
#  'helleborus viridis l.',
#  'herminium monorchis (l.)',
#  'herniaria ciliolata meld.',
#  'herniaria hirsuta l.',
#  'hesperis matronalis l.',
#  'hieracium alpinum l.',
#  'hieracium auricula [g].',
#  'hieracium lactucella wallr.',
#  'hieracium murorum agg.,',
#  'hieracium perproguinquum (zahn)',
#  'hieracium pilosella l..',
#  'hieracium umbellatum l.',
#  'himantoglossum hircinum (l.',
#  'hippocrepis comosa l.',
#  'hippophae rhamnoides l.',
#  'hippuris vulgaris l.',
#  'holcus lanatus l.',
#  'holcus mollis l.',
#  'hordelymus europaeus (l.)',
#  'hordeum murinum l.',
#  'hordeum secalinum schreb.',
#  'hornungia petraea (l.)',
#  'hypericum androsaemum l.',
#  'hypericum elodes l.',
#  'hypericum humifusum l.',
#  'hypericum montanum l.',
#  'hypericum perforatum l.',
#  'hypericum sp.',
#  'hypochoeris glabra l.',
#  'hypochoeris maculata l.',
#  'hypochoeris radicata l.',
#  'iberis amara l.',
#  'illecebrum verticillatum l.',
#  'impatiens noli-tangere l.',
#  'inula conyza dc.',
#  'inula crithmoides l.',
#  'inula helenium l.',
#  'iris foetidissima l.',
#  'isatis tinctoria l.',
#  'isolepis setacea (l.)',
#  'jasione montana ll.',
#  'juncus acutus l.',
#  'juncus articulatus l.',
#  'juncus biglumis l.',
#  'juncus bufonius l.',
#  'juncus bulbosus l.,',
#  'juncus filiformis l.',
#  'juncus gerardii lois.',
#  'juncus inflexus l.',
#  'juncus maritimus lam.',
#  'juncus sp.',
#  'juncus squarrosus l.',
#  'juncus trifidus l..',
#  'juncus triglumis l.',
#  'jungermannia spp.',
#  'kickxia spuria (l.)',
#  'knautia arvensis (l.)',
#  'koeleria cristata (l.)',
#  'koeleria vallesiana (honck.)',
#  'kohtrauschia prolifera (l.)',
#  'lactuca saligna l.',
#  'lactuca serriola l.',
#  'lactuca virosa l.',
#  'lamium album l.',
#  'lamium amplexicaule l.',
#  'lamium purpureum l.',
#  'lathyrus aphaca l.',
#  'lathyrus hirsutus l.',
#  'lathyrus japonicus willd.',
#  'lathyrus montanus bernh.',
#  'lathyrus nissolia l.',
#  'lathyrus palustris l.',
#  'lathyrus sylvestris l.',
#  'lavatera arborea l.',
#  'legousia hybrida (l.)',
#  'lemna trisulca l.',
#  'leontodon autumnalis l.',
#  'leontodon hispidus l.',
#  'leontodon taraxacoides (vill.)',
#  'leonurus cardiaca l.',
#  'lepidium campestre (l.)',
#  'lepidium latifolium l.',
#  'lepidium ruderale l.',
#  'leucorchis albida (l.)',
#  'ligusticum scoticum l.',
#  'limonium bellidifolium (gouan)',
#  'limonium bineroosum (g.e.sm.)',
#  'limonium binervosum (g.e.sm.)',
#  'limonium vulgare mill.',
#  'limosella aquatica l.',
#  'linaria arvensis agg.,',
#  'linaria repens (l.)',
#  'linnaea borealis l.',
#  'linum anglicum mill.',
#  'linum bienne mill.',
#  'linum perenne l.',
#  'littorella uniflora (l.)',
#  'lobelia dortmanna l.',
#  'lobelia urens l.',
#  'lolium bromoides huds.',
#  'lolium multiflorum lam.',
#  'lolium perenne l.',
#  'lolium temulentum l.',
#  'lonicera periclymenum l.',
#  'lotus corniculatus l.',
#  'lotus subbiflorus lag.',
#  'luronium natans (l.)',
#  'luzula campestris (l.)',
#  'luzula multiflora (retz.)',
#  'luzula spicata (l.)',
#  'luzula sylvatica (huds.)',
#  'lychnis coronaria (l.)',
#  'lychnis viscaria l.',
#  'lycopodium alpinum l.,',
#  'lycopodium annotinum l.,',
#  'lycopodium clavatum l.,',
#  'lycopodium selago l.,',
#  'lythrum hyssopifolia l.',
#  'lythrum salicaria l.',
#  'malva alcea l.',
#  'malva moschata ll.',
#  'malva neglecta wallr.',
#  'marchantia spp.',
#  'matricaria recutita l.',
#  'matthiola sinuata (l.)',
#  'meconopsis cambrica (l.)',
#  'medicago arabica (l.)',
#  'medicago falcata l.',
#  'medicago lupulina l.',
#  'medicago minima (l.)',
#  'medicago polymorpha l.',
#  'medicago sativa l.',
#  'melampyrum arvense l.',
#  'melampyrum cristatum l.',
#  'melampyrum sylvaticum l.',
#  'melica nutans l.',
#  'melica uniflora retz.',
#  'melilotus altissima thuill.',
#  'melittis melissophyllum l.',
#  'mentha aquatica l.',
#  'mentha arvensis l.',
#  'mentha rotundifolia (l.)',
#  'mentha x gentilis',
#  'mentha x niliaca',
#  'mentha x piperita',
#  'mentha x verticillata',
#  'mercurialis annua l.',
#  'minuartia hybrida (vill.)',
#  'minuartia sedoides (l.)',
#  'minuartia verna (l.)',
#  'moehringia trinervia (l.)',
#  'myosurus minimus l.',
#  'myrica gale l.',
#  'myriophyllum verticillatum l.',
#  'myrrhis odorata (l.)',
#  'narcissus majalis curt.',
#  'narcissus pseudonarcissus l.',
#  'narthecium ossifragum (l.)',
#  'neottia nidus-avis (l.',
#  'nymphaea alba l.',
#  'odontites verna (bell.)',
#  'onobrychis viciifolia scop.',
#  'ononis repens l.',
#  'ononis spinosa l.',
#  'onopordum acanthium l.',
#  'ophioglossum vulgatum l.',
#  'ophrys apifera huds.',
#  'ophrys muscifera huds.',
#  'orchis simia lam.',
#  'orchis ustulata l.',
#  'origanum vulgare l.',
#  'ornithogalum umbellatum l.',
#  'ornithopus perpusillus l.',
#  'orthilia secunda (l.)',
#  'osmunda regalis l.',
#  'otanthus maritimus (l.)',
#  'oxalis acetosella l.',
#  'oxyria digyna (l-)',
#  "oxytropis halleri bunge'",
#  'papaver argemone l.',
#  'papaver hybridum l.',
#  'parapholis strigosa (dumort.)',
#  'parentucellia viscosa (l.)',
#  'paris quadrifolia l.',
#  'parnassia palustris l.',
#  'pastinaca sativa l.',
#  'pedicularis palustris l.',
#  'pedicularis sylvatica l.',
#  'petasites hybridus (l.)',
#  'petroselinum segetum (l.)',
#  'peucedanum ostruthium (l.)',
#  'phragmites communis trin.',
#  'phyllitis scolopendrium (l.)',
#  'phyteuma tenerum r.schulz.',
#  'picris echioides l.',
#  'picris hieracioides l.',
#  'pimpinella major (l.)',
#  'pimpinella saxifraga l.',
#  'pinguicula alpina l.',
#  'pinguicula lusitanica l.',
#  'pinguicula vulgaris l.',
#  'pisum sativum l.',
#  'plantago coronopus l.',
#  'plantago lanceolata l.',
#  'plantago major l.',
#  'plantago maritima l.',
#  'plantago media l.',
#  'platanthera bifolia (l.)',
#  'platanthera? chlorantha (cust.)',
#  'poa alpina l.',
#  'poa angustifolia l.',
#  'poa annua l.',
#  'poa bulbosa l.',
#  'poa compressa l.,',
#  'poa nemoralis l.,',
#  'poa pratensis',
#  'poa subcaerulea sm.,',
#  'poa trivialis l.',
#  'polycarpon tetraphyllum (l.)',
#  'polygala vulgaris l.',
#  'polygonatum multiflorum (l.)',
#  'polygonatum odoratum (mill.)',
#  'polygonum amphibium l.',
#  'polygonum bistorta l.',
#  'polygonum convolvulus',
#  'polygonum hydropiper l.',
#  'polygonum minus huds.',
#  'polygonum persicaria l.',
#  'polygonum raii bab.',
#  'polygonum viviparum l.',
#  'polypodium filix-mas l.',
#  'polypodium vulgare l.',
#  'polypodium vulgare var.',
#  'polystichum aculeatum (l.)',
#  'polystichum lonchitis (l.)',
#  'polystichum setiferum (forsk.)',
#  'potamogeton acutifolius link',
#  'potamogeton berchtoldii fieb.',
#  'potamogeton crispus l.',
#  'potamogeton obtusifolius mert.',
#  'potamogeton pectinatus l.',
#  'potamogeton perfoliatus l..',
#  'potamogeton polygonifolius pourr.',
#  'potamogeton pusillus l.',
#  'potamogeton trichoides cham.',
#  'potentilla alba l.,',
#  'potentilla anglica laicharding',
#  'potentilla argentea l.!',
#  'potentilla erecta (l.)',
#  'potentilla fruticosa l.',
#  'potentilla palustris (l.)',
#  'potentilla reptans l.',
#  'potentilla rupestris l.',
#  'potentilla tabernaemontani aschers.',
#  'poterium sanguisorba l.',
#  'puccinellia distans (l.)',
#  'puccinellia fasciculata (torr)',
#  'puccinellia maritima :',
#  'puccinellia rupestris. (with.)',
#  'pulicaria dysenterica (l.)',
#  'pulicaria vulgaris gaertn.',
#  'pyrola minor l.',
#  'radiola linoides roth.',
#  'ranunculus arvensis l.',
#  'ranunculus auricomus l.',
#  'ranunculus bulbosus l.',
#  'ranunculus ficaria l.',
#  'ranunculus hederaceus l.',
#  'ranunculus lingua l.',
#  'ranunculus parviflorus l.',
#  'ranunculus repens l.',
#  'raphanus raphanistrum l.',
#  'reseda lutea l.',
#  'rhinathus? minor l.',
#  'rhynchospora alba (l.)',
#  'rhynchospora fusca (l.)',
#  'ribes alpinum l.',
#  'riccia spp.',
#  'rorippa islandica (oeder)',
#  'rorippa microphylla (boenn.',
#  'rorippa sylvestris (l.)',
#  'rosa arvensis huds.',
#  'rosa canina l.,',
#  'rosa canina var.',
#  'rosa rubiginosa l.',
#  'rosa villosa l.',
#  'rubia peregrina l.',
#  'rubus caesius l.',
#  'rubus chamaemorus l.',
#  'rubus idaeus l.',
#  'rubus saxatilis l.',
#  'rumex acetosella l.',
#  'rumex crispus l.',
#  'rumex maritimus l.',
#  'rumex sanguineus l.',
#  'rumex scutatus l.',
#  'ruppia maritima l.',
#  'sagina maritima g.don',
#  'sagina nodosa (l.)',
#  'sagina procumbens l.',
#  'sagina saginoides (l.)',
#  'sagina subulata (sw.)',
#  'salicornia europaea l.',
#  'salix alba l.',
#  'salix alba var.',
#  'salix arbuscula l.',
#  'salix aurita l.',
#  'salix caprea l.',
#  'salix cinerea l.',
#  'salix fragilis l.',
#  'salix fragilis var.',
#  'salix herbacea l.',
#  'salix sp.',
#  'salix triandra l.',
#  'salix viminalis l.',
#  'salsola kali l.',
#  'salvia pratensis l.',
#  'sambucus ebulus l',
#  'samolus valerandi l.',
#  'sanguisorba officinalis l.',
#  'saponaria officinalis l.',
#  'sarothamnus scoparius (l.)',
#  'saussurea alpina (l.)',
#  'saxifraga aizoides l.',
#  'saxifraga cespitosa l.',
#  'saxifraga granulata l.',
#  'saxifraga hirculus l.',
#  'saxifraga hypnoides l.',
#  'saxifraga moschata wulf.,',
#  'saxifraga nivalis l.',
#  'saxifraga oppositifolia l.',
#  'saxifraga sp.',
#  'saxifraga stellaris l.',
#  'saxifraga virginiensis michx.,',
#  'schoenoplectus lacustris (l.)',
#  'schoenoplectus triquetrus (l.)',
#  'schoenus nigricans l.',
#  'scilla autumnalis l.',
#  'scirpus maritimus l.',
#  'scirpus sylvaticus l.',
#  'scleranthus annuus l.',
#  'scleranthus perennis l.',
#  'scrophularia nodosa l.',
#  'scrophularia scorodonia l.',
#  'scrophularia vernalis l.',
#  'scutellaria minor huds.',
#  'sedum acre l.',
#  'sedum album l.',
#  'sedum dasyphyllum l.',
#  'sedum forsteranum sm.',
#  'sedum rosea (l.)',
#  'sedum sexangulare l.',
#  'sedum telphium l.',
#  'sedum villosum l.',
#  'selaginella selaginoides (l.)',
#  'senecio abrotanifolius l.,',
#  'senecio fluviatilis wallr.',
#  'senecio integrifolius l.',
#  'senecio jacobaea l.',
#  'senecio sylvaticus l.',
#  'senecio viscosus l.',
#  'senecio vulgaris l.',
#  'serratula tinctoria l.',
#  'sesleria caerulea (l.)',
#  'sherardia arvensis l.',
#  'sibbaldia procumbens l.',
#  'sibthorpia europaea l.',
#  'sieglingia decumbens. (l.)',
#  'silene acaulis (l.)',
#  'silene armeria l.',
#  'silene conoidea l..',
#  'silene dioica (l.)',
#  'silene gallica l.',
#  'silene italica (l.)',
#  'silene noctiflora l.',
#  'silene nutans l.',
#  'silene otites (l.)',
#  'silene vulgaris (moench)',
#  'silene vulgaris subsp.',
#  'silybum marianum (l.)',
#  'sinapis alba l.',
#  'sinapis arvensis l.',
#  'sisum amomum l.',
#  'sisymbrium irio l.',
#  'sisymbrium latifolium l.',
#  'sisymbrium officinale (l.)',
#  'smyrnium olusatrum l.',
#  'solidago virgaurea l..',
#  'sonchus arvensis l.',
#  'sparganium erectum l.',
#  'sparganium minimum wallr.',
#  'spergula arvensis l.',
#  'spergularia media (l.)',
#  'spergularia sp.',
#  'spiranthes spiralis (l.',
#  'stachys arvensis (l.)',
#  'stachys palustris l.',
#  'staphylea pinnata l.',
#  'stellaria alcine grimm!',
#  'stellaria holostea l.',
#  'stellaria nemorum l.',
#  'stipa pennata l.,',
#  'stratiotes aloides l.',
#  'suaeda fruticosa forsk.',
#  'suaeda maritima (l.)',
#  'swertia perennis l.,',
#  'taraxacum officinale weber,',
#  'teucrium scordium l.',
#  'teucrium scorodonia l.',
#  'téesdalia nudicaulis (l.)',
#  'thalictrum alpinum l.',
#  'thalictrum minus l.',
#  'thelycrania sericea (l.)',
#  'thelypteris oreopteris (ehrh.)',
#  'thelypteris palustris schott',
#  'thelypteris phegopteris (l.)',
#  'thesium humifusum dc.',
#  'thlaspi alpestre l.',
#  'thlaspi arvense l.',
#  'thlaspi perfoliatum l.',
#  'tiagopogon porrifolius l.',
#  'tilia cordata mill.',
#  'trichophorum cespitosum (l.)',
#  'trientalis europaea l.',
#  'trifolium arvense l.',
#  'trifolium campestre schreb.',
#  'trifolium dubium sibth.',
#  'trifolium fragiferum l.',
#  'trifolium glomeratum l.',
#  'trifolium medium l.-^',
#  'trifolium ochroleucon huds.',
#  'trifolium ornithopodioides l.',
#  'trifolium pratense l.',
#  'trifolium repens.',
#  'trifolium scabrum l.',
#  'trifolium squamosum l.',
#  'trifolium striatum l.',
#  'trifolium subterranean l.',
#  'triglochin maritima l.',
#  'triglochin palustris l.',
#  'trinia glauca (l.)',
#  'triplemaspermum maritimum (l.)',
#  'trisetum flavescens (l.)',
#  'trollius europaeus l.',
#  'tuberaria guttata (l.)',
#  'turritis glabra l.',
#  'tüssilago farfara l.',
#  'typha angustifolia l.',
#  'ulex europaeus l.',
#  'ulmus glabra huds.',
#  'ulmus procera salisb.',
#  'umbilicus rupestris (salisb.)',
#  'urtica pilulifera l.',
#  'vaccinium myrtillus l.',
#  'vaccinium ovalifolium sm.',
#  'vaccinium oxycoccus l.',
#  'veronica alpina l.',
#  'veronica beccabunga l.',
#  'veronica hederifolia l.',
#  'veronica officinalis l.',
#  'veronica scutellata l.',
#  'veronica serpyllifolia l.',
#  'veronica spicata l.',
#  'veronica triphyllos l.',
#  'viburnum lantana l.',
#  'viburnum opulus l.',
#  'vicia cracca l.',
#  'vicia hirsuta (l.)',
#  'vicia lathyroides l.',
#  'vicia lutea l.',
#  'vicia orobus dc.',
#  'vicia sativa l.',
#  'vicia sepium l.',
#  'vicia sylvatica l.',
#  'vicia tetrasperma (l.)',
#  'viola hirta l.',
#  'viola lutea huds.',
#  'viola riviniana rchb.',
#  'viola tricolor l.',
#  'violaspp.',
#  'vulpia bromoides (l.)',
#  'vulpia membranacea (l.)',
#  'vulpia myuros (l.)',
#  'wahlenbergia hederacea (l.)',
#  'woodsia ilvensis r.br.',
#  'zannichellia palustris l.',
#  'zostera angustifolia (hornem.)',
#  'zostera marina l.'}

# %%
def get_description_pairs(gold_set, eval_set, pairs):

    desc_pairs = ()

    for pair in pairs:
        if pair[0] in gold_set and pair[1] in eval_set:
            yield pair

# %%
pairs = (family_gold & family_eval)

gold_desc = []
eval_desc = []

for pair in pairs:
    fam_ = pair[0]
    sp_ = pair[1]
    desc_gold = df_gold[(df_gold["family_name"] == fam_) & (df_gold["species_name"] == sp_)]["description"].values[0]
    desc_eval = df_eval[(df_eval["family_name"] == fam_) & (df_eval["species_name"] == sp_)]["description"].values[0]

    if pd.isna(desc_gold) or pd.isna(desc_eval):
        continue
    gold_desc.append(desc_gold)
    eval_desc.append(desc_eval)

# %%
gold_desc
# Out:
# ['teucrium - scorodonia ta.',
#  'folder 1. potentilla verna aschers., flora scotica ed. 1, 270 (1777). "vincents rock & gloddaeth" [jl]. "potentill: vern: scotland. mr. yald" [jl]. "ne 26. torment. var. with 5 pet.-found near the top of creg-chaillech" [stuart]; *potentilla verna [perennial, may and june]" [jl]. [probably contains a mixture of p. tabernaemontani htfoot and p. crantzit (crantz) g.beck ex fritsch.]',
#  '1 folder. ononis spinosa ta.',
#  'folder 1. orchis bifolia [g], flora scotica ed. 1, 512 (1777)',
#  'folder 1. tormentilla reptans l., flora scotica ed. 1, 273 (1777). "tormentilla reptans near newent. solander" [jl]. "pentaphyllum reptans, in the road to percy lodge" [jl]. [specimens marked *x" in pencil are p. anglica or hybrids].',
#  'triticum repens [ta], flora scotica ed. 1, 109 (1777). i. cites lin.; huds.; ray\'s syn. 390. \r\n ii. "dogs-grass or couch-grass. in fields & hedges almost everywhere, from june to august. it appears from the sample marked, à [var. aristatum baumg.], that the spikes are sometimes a little bearded" [jl]. \r\n iii. "chepstow bridge" [jl].',
#  'folder 1. trollius europaeus [ta]. i. "trollius europaeus lin: near ambleside in westmoreland, & c." [jl]. [most probably collected on way to scotland via keswick and carlisle; jl and pennant stayed at ambleside on night of 22 may 1772.]',
#  'folder 1. pimpinella dioica huds. [g]; p. pumila jacquin. "jacquin calls this pimpinella pumila but the seeds & habit agree best with the genus of seseli, though the involucella are rarely seen"',
#  'folder 1. salix cinerea [ta]. "salix cinerea linn. flora suecica" [jes]. "cumberland" [jl].',
#  'folder 1. centunculus minimus [g], flora scotica ed. 1, 119 (1777). i. cites addendum of ray\'s syn. \r\n ii. "bastard pimpernel. june & july. upon gravelly ground where the water has stood in the winter; as near the powder mills on hounslow heath, & about a mile beyond bracknel in the road to oakingham, berkshire, by the road side a little before you come to the turnpike" [jl].',
#  '1 folder. epilobium. montanum [ta]. i. "epilobium montanum" [jl]. \r\n ii. "bulls grove (grove in bulstrode park]" [jl].',
#  'astragalus epiglotis [ta]\r\ni. "*an astragalus arenarius? seu quid? in anglia prope portsmouth inventa a d. banks" [jl] \r\n ii. "astragalus arenarius" [? banks]',
#  'folder 1. osmunda regalis [ta]. i. "osmunda regalis a var: foliol: dentatis nast" [jl]. \r\n ii. "common in our moist woods; in a little wood, for instance, near cawston decoy, about 2 miles from heydon [in \'norfolk\']" [b]',
#  'folder 1. lycopodium alpinum.\r\ni. cites linn. \r\n ii. on the summits of the highest mountains in the north of england, & in wales. august. these specimens i gathered on the top of ingleborough hill in craven, yorkshire [jl].',
#  'limosella aquatica [ta].',
#  '1 folder. scirpus caespitosus [ta], flora scotica ed. 1, 87, 1080 (1777).\r\ni. cites linn. sp. pl. 71; ray\'s syn. 429. \r\n ii. *dwarf clubrush. july. this grows in marshy & heathy places very common in the north of england, but more rare in the south. i have seen it on hounslow heath in boggy places between twickenham & hampton; and on bagshot heath at virginy water, and on the bogs near croydon. it varies exceedingly in size, as may be seen by comparing the upper samples with the two undermost" [jl]. \r\n iii. "scirpus caespitosus" [jl]. \r\n iv. "ne. 62. mossy ground in bredalbane-passim- called in galic cip-cheann-du\'- much esteemed as affording the earliest relief to the cattle in spring" [stuart]; "scirpus caespitosus" [jl].',
#  'folder 1. plantago maritima [ta]. "plantago maritima. newfound-land. mr. banks" [jl].',
#  'aira cristata [ta]. i. cites moris. hist. ox. sect. 8, t. 4, f. 7; ray\'s syn. 396. \r\n ii. "cristed hairgrass. june. this grows on heaths & barren sandy places" [jl]. \r\n iii. "aira cristata" [jl].',
#  '1 folder. aira aquatica [ta], flora scotica ed. 1, 94 (1777). this is frequently found growing in the water by the sides of rivulets [jl]. i. cites linn.; ray\'s syn. 402. \r\n ii. "water hair-grass. may & june." [jl]. \r\n iii. "aira aquatica" [jl].',
#  'folder 1. vicia lathyroides [g]. "vicia lathyroides?" (b); "mr. bryant" [jl].',
#  'anthriscus cerefolium [ta]',
#  'folder 1. galium anglicum huds. [g]. i. "gal: spinosum. sem: glabra ergo non g: parisiense. mr. banks, at farningham 10 m: beyond eltham in kent on the walls of a house" [jl].',
#  'alisma natans [ta]',
#  'folder 1. orchis pyramidalis [g and ta], flora scotica ed. 1, 513 4777)',
#  'folder 1. poa pratensis [?]. i. "fl: clod." [jl]; "only p. pratensis". [?]. \r\n ii. "poa setacea. poa panicula diffusa, spiculis unifloris pubescentibus, foliis radicalibus setaceis. huds. angl. 34. an diversa a poa angustifolia. non videtur" [?].',
#  'folder 1. lobelia urens [g]',
#  '1 folder. sedum dasyphyllum [ta]. i. "tillea muscosa. i can find this plant at all times of the year; in great perfection as the snow in winter is gone, we makes me think that it must at least be biennial" [b]; "by mr. bryant" [jl] \r\n ii. "dasyphyl: - bulls: [bulstrode park]" [jl].',
#  'folder 1. poa alpina huds, [g]. i. [on reverse:] *poa panicula difusa ramosissima, spiculis sexfloris cordatis. flor. suec, 79" p solander]. \r\n ii. "mrs hyde" [jl]; "poa vivipara" [ta]. [three specimens of var. vivipara l. and one of typical p. alpina]',
#  'centaurea cyanus [ta]. i. "langley [buckinghamshire]" [jl]',
#  'ballota nigra [ta], "ballota alba weston supra mare"[jl]',
#  '1 folder. hippuris vulgaris ta. i. "hippuris vulgaris" jl. \r\n ii. on loose label: hippuris vulgaris. mare\'s tail?',
#  "folder 1. festuca glabra, fl: scot: [ta], flora scotica ed. 1, 1085 (1777). i. 'festuca gallovidiensis of d' walker. ardbigland in galloway. scotland' [jl]. \r\n ii. 'festuca gallovidiensis d* walker. ardbiglen' [?]. \r\n iii. 'festuca glabra flo. scot.: 1085. certainly' [?].",
#  "festuca laevigata sol. and f. cambrica fl. angl. [ed. 2, 1: 45] [ta]. i. 'festuca laevigata of banks & solander. upon the rocks on the top of snowdon in wales' [jl]. \r\n ii. 'festuca cambrica huds: flo. angl. 45. certainly' [?]. \r\n iii. 'laevigata. fest: panicula oblonga subcoarctata erecta laevis aristata, foliis latiusculis compressis glabris. hab: in summo montis snowdon & glyder. culmus ascendens glabra pedalis, folia radicalia, plurima, latiuscula, compressa, laevia, longa, interdum culmo vix breviora, caulina breviora. panicula oblonga, subcoarctata, erecta, biuncialis. rami breves, raro subdivisi. spicula oblongae, laeves, quadriflorae. calycis gluma bivalvis, valvulae lanceolata, inferior paulo brevior. corol: bivalvis, valvulae lanceolatae acuta calyce 1/3 longiores, exterior in : aristam valvula duplo breviosem terminata, paulo brevior. obs: facie distinguuntur a f. durius: rubra folius latioribus & spiculis majusculis laevigatis' [jl] [possibly a copy of solander's description of f faevigata]. ]",
#  'carduus crispus [g]',
#  'folder 1. carex divisa-bad specimen [g]. i. "carex leporina? specimen imperfectum? in a small piece of meadow ground between kirby beedon & brammeton about 4 miles from norwich. m* bryant, who suppos\'d it to be c. capitata" [jl]. \r\n ii. "in the year 1762 or 1763, i gathered some quantity of this plant in a small piece of meadow ground, between kirby beedon & brammerton, about 4 miles from norwich, and have never met with it since. i make it the carex capitata—i sent some of it to d\' hope, and have given all the rest away, except this single specimen, which is at your service, and heartily wish it may prove to be what you wanted—i intend looking for it again, next season—we know nothing of the carex divisa—and i should be obliged to you for your opinion upon that plant; for i am inclined to think that some mistake has been committed here—did you ever search for it in the particular places, as directed?" [b]; "certainly not the c. capitata. it seems to me to be a very imperfect specimen of c. leporina, or perhaps uliginosa, but nothing certain can be determined from a single sample in so vague a genus" [jl]. description_type: folder',
#  'folder 1. aira canescens [g]. "aira canescens at cley, near the haven\'s mouth, in loose, blowing sands, very plentifully" [b].',
#  '1 folder. rumex sanguineus [ta].',
#  '1 sheet. carex digitata g. [g]. i. [on reverse:] carex digitata lin: kew hort: may" [jl].',
#  'folder 1. campanula rapunculus [ta]',
#  'folder 1. trifolium agrarium g. i. *an trifol: procumbens? percy lodge [near colnbrook], & pastures. june" [jl]. \r\n [specimen on a right side of folder is t: dubium.]',
#  'geranium pyrenaicum [g]. i. "bulls: [bulstrode park]" [jl].',
#  'folder 1. dianthus arenarius hud. [ta]. i. "cheddar brought into a garden" [jl]. \r\n ii. "dianthus arenarius the true. sent by mr. banks to bulstrode from cheddar" [jl]',
#  'folder 1. carex intermedia-singular variety-g. [g]. "carex disticha with a single spike, which approaches nearest to my carex capitata; and not the variety of the carex leporina as you supposed. my c. capitata was an upright plant—the c. leporina is decumbent" [b]; "bryant" [jl]. \r\n ii. "i cannot pronounce for certain what species this is from one sample, only, & that in its seeding state only, in so variable a genus as the carex. it has the habit of a carex, & there seems to have been 1 flower at top. that was male. had i seen it in a younger state, i might possibly have pronounced it with some certainty. some starved specimens of my c: arenar: & distica. it bids fair likewise for hudson\'s c. divisa, if he has any meaning in it, but the stalk is round" [jl]. \r\n iii. "this carex m\' yalden found on dorsetshire near weymouth. he sent some specimens of newberry in oxford who was inclined to think it was no carex, but the schoenus fuscus. spec: pl: append: 1664. it does not seem to be that for the following reason, the stalk is 3-quet at the top especially, the leaves are not filiform: but ensiforme & micheli [nov. plant. gen., p. 53, ordo 1, no. 2. (1729)] says of it, crescit apud nos cum antecedenti (viz. sch. albo) a qua differre non vide-tur nisi paniculae colore, qui prophtfootter vetustatem forte variat. it is hudson\'s c. divisa given to m\' pitchford" [jl]. description_type: folder',
#  '1 folder. picris hieracioides? [g].',
#  '- folder 1. urtica pilulifera [g].\r\n  - cites ray\'s syn. 140.\r\n  - "roman nettle. i gathered these samples within the town wall at yarmouth in norfolk" [jl].\r\n  - "urtica pilulifera, at gorlston, about a mile from yarmouth; the whole town is over run with it; & is more common than the urtica dioica" [b]. [according to r.d. meikle, this plant now (1977) completely disappeared from gorlston].',
#  '1 folder. salsola kali ta. i. "caldy isl: [caldy island off the dyfed (pembrokeshire) coast near tenby)" jl.',
#  'folder 1. thalictrum minus [ta]. i. "holkam, cambridge" [jl].',
#  '1 folder narcissus poeticus? and n. angustifolius? g.',
#  'folder 1. dianthus glaucus? [ta]. i. "dianthus glaucus pro certo. kew. respondet. fig: dillen:" [jl]. \r\n ii. "this aiton [william aiton] says is the dianthus glaucus. white flowers with a purple circle. kew. compare it with dianth: deltoides"[jl].',
#  '1 folder. impatiens noli me tangere [g]',
#  '1 folder. saxifraga hypnoides? [g]. i. "by mr. banks from newfoundland" [jl]. [s. aypnoides occurs in northwestern europe.]',
#  '1 folder. avena nuda [ta]. i. cites ray\'s syn. 389; moris. hist. s. 8, t. 7, f. 4. \r\n ii. "naked oats or pilcorn. this is sown in some parts of england, as in cornwal & staffordshire. july" [jl]. \r\n iii. "avena nuda" [jl].',
#  '1 folder. carex riparia ta; cacuta varietas a-huds. & lightfoot g. i. "carex acuta (var: ruffa) lin: carex riparia. curtis" - ly.',
#  'folder 1. juncus spicatus [ta], flora scotica ed. 1, 187, 1121 (1777). i. "j. spicatus. ben lomond. 2 specimens" [jl]. \r\n ii. "juncus spicatus" [?].',
#  'folder 1. juncus buffonius ta.',
#  'folder 1. stipa pennata [g]. i. cites linn.; ray\'s syn. 393; moris. hist. ox. sect. 8, t. 7, f. 9. \r\n ii. "feather grass. july. this has been found growing wild in england, upon the rocks by the side of long sleadale near kendal in westmoreland" [jl]. \r\n iii. "stipa pennata" [jl].',
#  'veronica alpina [g]. i "veronica alpina. found on the side of a rivulet, about half way up ben-nevis; and upon the north side of a hill to the west of garr more in scotland, by m* dickson [james dickson]. 1786" [jl]. [un mounted specimen in loose packet.',
#  'folder 1. linum angustifolium [g].\r\n"narrow-leaved wild flax. july. this is a rare english plant but grows plentifully in the pastures by the seaside about st. ives & truro in cornwall. it has been found likewise in similar places near the sea coast in sussex & kent" [jl]; "the flowers of this sp: are not 1/2 so large as those of the perenne, nor so deep a blue" [ta].',
#  'folder 1. alisma damasonium [ta]',
#  '1 folder. avena sativa [ta]. [see under a. fatua var. glabrata folder 1]',
#  'folder 1. crepis foetida [ta]. "crepis foetida at greenhith in kent" [jl].',
#  'folder 1. sium erectum [ta]; s. angustifolium [g], flora scotica ed. 1, 161 (1777). i. "i make this the sium erectum huds. and now the sium angustifolium linn. sp. pl. 24 id. app. p. 1672-but i cannot understand what linn. means by the folia basi hastata; for i can discover no such property in it. the plant is common in my neighbourhood [heydon, norfolk]" [b]',
#  'folder 1. circaea alpina [ta], flora scotica ed. 1, 80, 1115 (1777). "alpine enchanters nightshade. july & aug. this is one of the rarer natives of england. it grows at the foot of some of the mountains in yorkshire & westmoreland" [jl]. \r\n ii. "circaea alpina. newfoundland. | mr. banks" [jl] [p.h. raven identified this specimen as c. alpina].',
#  '1 folder rosa rubiginosa l. var. rubiginosa',
#  'folder 1. hypericum montanum [g]',
#  '1 folder. polygonum bistorta [ta]. i. "polygonum bistorta. lin."[jl]',
#  '1 folder sibaldia procumbens [ta]. i. "ben lomond" [jl]. \r\n ii. no. 67. ben-achaladarin in glenurchy" [stuart];\'sibbaldia\' [jl].:',
#  'folder 1. schoenus compressus (ta), flora scotica ed. 1, 87, 1115 (1777). i. cites linn., sp. pl. 65; ray\'s syn. 425.  \r\n ii. "compressed bastard cyperus, may. this is found in boggy meadows, but not common" [jl]. \r\n iii. [in pencil:] "the loose schoenus compressus or brunneus. uxb: [uxbridge] moor" [jl].',
#  '1 folder. althea officinalis [ta]',
#  '1 folder. carex acuta [ta]; huds. and curtis [g]; c. paludosa linn. trans. g. [g]. i. "carex acuta" [b]; "capsules oval & striated, in c. caespitos. round & not striate" [jl]. \r\n ii. "cricklade hill turnpike. the true c. acuta of curtis & dr good---ugh" [jl]. \r\n iii "carex acuta (var: y huds:)" [jl].',
#  'folder 1. cerastium arvense [ta]. i. "cerastium arvense. this must be right tho\' the leaves are hoary" [jl]. \r\n ii. "cerastium arvense. very common in norfolk. why does lin. put the word glabris in his specific description in opposition to truth & the testimony of all authors" [b].',
#  "1 folder. erysimum officinale [ta], 'flora scotica ed. 1, 354 (1777).'",
#  'folder 1. geranium rotundifolium [g].',
#  'folder 1. onopordum acanthium [g].',
#  'lepidium latifolium [ta].',
#  'folder 1. cornus suecica [ta], flora scotica ed. 1, 119, 1116 (1777). i. cites linn. sp. pl. 118; ray\'s syn. 261. \r\n ii. "dwarf honeysuckle. june. upon the cheviot hills in northumberland; & in a place call\'d hold of hurkam upon the moors north of pickering near malton, yorkshire" [jl]. \r\n iii. "ross shire. l. broom [loch broom]"[jl]',
#  'folder 1. melissa calamintha [g], i. "melissa calamintha. devonshire, cornwal & c." [jl]. \r\n ii. "common calamint near dartford in the lune" [jl].',
#  'folder 1. frankenia laevis [ta]. "frankenia laevis. at cley, on the beach towards salthouse [small villages on the north norfolk coast near blakeney]" [b].',
#  '1 folder. pinguicula vulgaris [ta]. i. "pinguicula vulgaris" [jl]  \r\n 1 loose sheet. ii. [on reverse:] "\'pinguicula vulgaris lin: e lapponia missa. corolla fauce villoso-gland-ulosa" [jl]',
#  '1 sheet. aquilegia alpina ta. i. "aquilegia alpina l: ex helvetia accepi a d. banks" jl. [one of banks\' specimens from switzerland.)',
#  '1 folder. trifolium fragiferum ta. i. "this by dr. hope. q: is it scotch" [jl]. \r\n ii. "chester & frogmore garden naturaly" [jl].',
#  'folder 1. juncus squarrosus ta.',
#  '1 folder. statice reticulata [ta]. i. "statice reticulata lin: cley salt marshes norfolk" [jl].',
#  'folder 1. origanum onites? ta; o. vulgare g. i. "this pot marjoram of the gardens. hudson says is no other than a var: of orig: vulgare" jl.',
#  'folder 1. veronica hederifolia (7a). catal i. "veronica hederifolia" [jl].',
#  'folder 1. medicago falcata [ta]\r\ni. "medicago falcata from norfolk, mr. hudson" [jl] \r\n ii. "medicago falcata. very plentifully on dry banks on the south west side of norwich" [b]',
#  'folder 1. vaccinium myrtillus [ta]. i. "vaccinium myrtillus" [jl]',
#  '1 folder. imperatoria ostruthium [ta], flora scotica ed. 1, 168, 1118 (1777)',
#  'folder 1. carex extensa linn.\r\n\' trans. v.2. d\' goodenough, vars.\r\n[g]. i. "i can make this carex\r\nagree w? nothing in the sp. pl. so\r\nwell, as w*^ the filiformis but there\r\nis an obscurity in the latter part of\r\nthe specific character, w*, i am\r\nafraid, i do not understand-\r\ninferiore foliolo proprio breviore-\r\nwt i translate thus-the bottom\r\nspike is shorter than its own floral\r\nleaf. and if this be the true sense\r\nof the author; the difference between the one & the other is so\r\n" great, that, allowing this carex to\r\n\' be the filiformis, he could never\r\nmean to draw the comparison. i\r\nfound it, june 20^ 1776, amongst\r\nthe stones & sand on cley [on\r\nnorth norfolk coast near blakeney]\r\nbeach. the leaves were nearly\r\nconvolute" [b]; "the male spike\r\nof c. filiform: is long, not sessile,\r\nthe female ones only two, & the\r\ncapsules a little downy" [jl]. [on\r\nreverse of label:] \r\n ii. "carex filiformis? lin. i think this can never be\r\n. a var. of the c. pallescens, for many\r\n* reasons; and for one in particular;\r\nbecause the parts of fructification\r\nare so different-i have given you a\r\nfig. of each. fig. 1 is the capsula',
#  'folder 1. scirpus lacustris [ta], flora scotica ed. 1, 88 (1777); s. triquetter [g]. i. cites linn. sp. pl. 72; ray\'s syn. 428. \r\n ii. "the bullrush. this is very common in ponds & rivers" [jl]. \r\n iii. "scirpus lacustris" [jl].',
#  'folder 1. polypodium phegopteris [g], flora scotica ed. 1, 669 (1777). i. cites linn. sp. pl.; ray\'s syn. 122. \r\n ii. "i gathered this near orton in westmoreland going from kendal" [jl].',
#  '1 folder. chenopodium murale ta. i. "according to the specimens in the hort. siccus of lin: this is the chenopodium murale, not serotinum" jl. \r\n ii. "ch: serot: lin: has pretty large deltoid angular leaves, but no flowers, not unlike our viride" jl. \r\n iii. *pool poole in dorset" jl.',
#  'folder 1. polygonum maritimum? [g]. i. "polygonum maritimum: from abermeney ferry in anglesey" jl.',
#  'bromus squarrosus? [ta]. i. "island in milford haven. vide or non brom: squarrosus" [jl].',
#  '1 folder, staphylea pinnata ta. i. "bladder nut. bulbs: bulstrode park duck island" jl.',
#  'folder 1. euphorbia paralias [g]. cites ray\'s syn. 312. \r\n ii. "sea spurge. this is a native of our sea coasts; but the specimen here exhibited grew in a garden, and has therefore an appearance somewhat different from the plants which grow wild" [jl]. \r\n iii. "euphorbia paralias lin: ex horto" [jl].',
#  "folder 1. lycopodium clavatum.\r\ni. cites linn. \r\n ii. anglis. club-moss. july & aug'. this plant is not very uncommon on heaths, as on bagshot, hounslow, hampstead heaths &c. [jl].",
#  'artemisia vulgaris [ta]',
#  'folder 1. anthemis nobilis [jl], flora scotica ed. 1, 493 (1777). "an: anthemis nobilis. hounslow heath" [jl].',
#  'sisybrium sylvestre [ta].',
#  'bidens cernua [ta]. i. "coreopsis bidens near norwich" [pitchford]; "a very pretty variety of the bidens cernua. mr. pitchford" [jl]',
#  '1 folder. sinapis arvensis [ta]',
#  'folder 1. trifolium striatum [ai i. "trifol: striat: buddle\'s hort: sic: kew green. percy l: [percy lodge] park by the greenhouse. june" jl. \r\n ii. "this is what i took for the trifolium ochroleucon but i imagine it is only t: striatum"?; "certainly t: striatum" jl. :',
#  'folder 2. tormentilla erecta huds. and t. officinalis curtis [g].',
#  'folder 1. senecio sarracenicus [ta].',
#  'cheiranthus cheiri [ta].',
#  'folder 1. atriplex littoralis l.\r\n"dorsetshire i think at weymouth" [jl]',
#  '1 folder. ononis arvensis ta.',
#  'folder 1. ophrys apifera [ta]',
#  '1 folder. fragaria vesca [ta]; hautboy strawberry [name given to e. moschata duchesne] [g].',
#  'geranium dissectum [g].',
#  'lathyrus sylvestris [ta]\r\ni. "lathyrus sylvestris, at brundale near blosfield. mr. charles bryant" [b; handwriting of henry bryant]',
#  '1 folder. senecio abrotanifolius [ta];? not an english plant [g]. i- "senecio erucifolius distinguitur à jacobaea, altitudine & calycis apicibus non emortuis ut in jacobaea. in sepibus & dumetis frequen* aug: planta dubia an s. abrotanifolius? lin:" [jl]. [species found in the central and eastern alps, the carpathians and the mountains of the balkan peninsula.]',
#  'folder 1. poa bulbosa [?]. i. "all from italy given by m\' aiton [william aiton]" [jl]. \r\n ii. "fillegible]... icum spicis digitalis flosculis solitariis sessilibus uno versu disporitis. gramen dactylon, radie repente, sive officinarum. scheuch. gram. 104. panicum dactylon. linn. sp. pl. 85" [? solander]. \r\n iii. "poa bulbosa. poa panicula bensa, spiculis quadrifloris pubescentibus, culmorum basi suberosa. gramen xerampelinum ec. scheuch. gram. 185. de [illegible]... inilio linnei non lacet. poa alpina l. variet. est hujus speciei. 1. gramen arvense panicula crispa. dank. pin. 3. prodr. 6 theaw. p. 32" [? solander]. [specimen between the two of typical p bulbosa is var. vivipara kocl.]',
#  'saxifraga caespitosa [ta]. i. "saxifraga caespitosa lin: a d: banks accepi. in helvetia collecta?" [jl]. [specimen one of banks\' from switzerland; s. caespitosa occurs in arctic and sub-arctic europe, south to northern britain and central urals but not as far as switzerland.]',
#  'genista tinctoria [ta]',
#  'folder 1. pedicularis palustris [ta]; p. sylvatica [g]. i. "pedicularis palustris lin:" [jl].',
#  'folder 1. salix aurita [g]. "salix aurita near iver heath, by the orchis field" [jl].',
#  'sisymbrium amphibium [ta], flora scotica ed. 1, 352 (1777); sisymbrium terrestre [g].',
#  '1 folder. convallaria majalis l.',
#  '1 folder. trifolium melilotus officinalis ta, flora scotica ed. 1, 402 (1777). i. "q: what melilot. percy lodge [near colnbrook]"[jl]',
#  'folder 1. juncus tenaseia linn. and j. bufonius-b-huds. g.',
#  '1 folder. asarum europaeum ta.',
#  '1 folder. senecio vulgaris (cl. "ex hort: meo" [jl].',
#  'iberis amara [ta].',
#  'hypericum quadrangulare [ta]',
#  'folder 1. lepidium ruderale l.',
#  'folder 1. sedum album? [g]. i. "by mr. banks from newfoundland" [jl]. [specimens can be identified only as sedum sp.]',
#  '1 folder. carduus marianus [ta], flora scotica ed. 1, 454 (1777).',
#  'folder 1. thesium linophyllum [ta]',
#  '1 folder. festuca myuros [ta].',
#  'folder 1. leontodon taraxacum var. palustre [g]. "leontodon (palustre). calyce toto erecto glabro. scapo cavo uniflorae- lyon\'s fasc. 48 no. 89-i believe this is common on moorish, rotten ground-i consider it only, as a variety of the taraxacum, lin. the squamce, though erect in the green plant, become a little reflex, when dry" [b]',
#  '1 folder. allium schoenoprasum l.',
#  'folder 1. asplenium scolopendrium [ta], flora scotica ed. 1, 660 (1777).',
#  'folder 1. spergula nodosa [ta], flora scotica ed. 1, 244 (1777). i. "arenaria saxifrag: palustris on dry banks near the sea & from sandwich towards ramsgate" [?]. \r\n ii. "spergula nodosa. on cley - beach and is very common on our bogs and low grounds" [b].',
#  'folder 1. delphinium \'consolida.ta] i. "in the cornfields abt bowthorp, baber & carlham near norwich, and in the cornfields ab! barton mills, suffolk, very plentifully" b; "bryant" jl.',
#  'stachys palustris ta.',
#  'folder 1. triticum repens [ta]; vars. maritima [g]. i. "gramen caninum maritimum spica triticea nostras. ray. syn. p. 390. no. 3" [jl]. \r\n ii. "wheat-grass, dog\'s grass, couch-grass. on the essex-coast, by the thames side, just below grayes thorock in great plenty. this is a very singular variety of the "triticum repens much altered from the usual appearance by growing in salt marshes. the leaves are glaucous, convoluted, & pungent, like the triticum junceum, so that i at first imagin\'d it was that, but the calyces are not truncated at their apices. july" [jl]. \r\n iii. "triticum repens var:" [jl].',
#  'folder 1. chenopodium polyspermum ta. i. "bit of chenopod: polysperm:" jl. \r\n ii. "chenopodium polyspermum. lin:" jl.',
#  'hipocrepis comosa [ta]',
#  'campanula hybrida [ta]',
#  'folder 1. chelidonium glaucium - [g], flora scotica ed. 1, 279 (1777). i. "portland"[jl]',
#  '1 folder. anthriscus caucalis [ta], flora scotica ed. 1, 166 (1777)',
#  '1 folder. fumaria officinalis [ta]. i. _ *cowleyfield [near uxbridge in middlesex]. common fumitory" - ql]',
#  '1 folder. carex atrata [ta]. i. "bentesgerry. ne 3" [? "c. atrata" [jl]. ;',
#  'folder 1. trifolium maritimum catal [g]. i. "from mr. banks. trif: maritim; certe" jl. \r\n ii. "aust\'s passage & c." jl.',
#  'saxifraga nivalis [ta]. i. "a garden specimen" [ta].',
#  'lotus corniculatus d hirsuta [g]',
#  "folder 1. rubia tinctoria » [ta]; r. peregrina huds. [g]. i. cites ray's syn. 223.",
#  '1 sheet. carex inflata ta; huds. and lightfoot, and c. vesicaria linn. g [g]. i. "c: vesicaria var: p huds: (var: y lin: spec:) tho\' it has some pretentions to c: ruffa gui - 189 lin: a var: of c: acuta" [jl]; [on reverse of label:] "ne 2. this i found amongst the carex vesicaria" [?]; "hudson says this is his carex inflata. may [17]69" [jl]. \r\n ii. "carex hirta" [b]; *c. inflata" ur].',
#  'folder 1. hypochoeris maculata [ta].\r\ni. cites ray\'s syn. [?] 167. \r\n ii. "spotted hawkweed. july. in barren mountainous pastures, but very rarely, as upon the banks of the devil\'s ditch near reche, not far from newmarket, and on bernuk heath in northamptonshire" [jl].',
#  '1 folder. fanunculus hederaceus [ta].',
#  'veronica beccabunga [ta]. * "veronica beccabunga" [jl].',
#  'folder 1. salix capraea [g]. "s. capraea fem. gulch well" [jl]. [specimen on left is s. cinerea subsp. oleifolia macreight.]',
#  '1 folder. dipsacus pilosus [ta]',
#  'folder 1. vaccinium myrtillus?? [ta]. i. "vaccinium myrtillus i believe. newfoundland. mr. banks" ([jl]',
#  '1 folder. drosera longifolia ta,\r\nflora scotica ed. 1, 175, 1098 (1777). i. "drosera longifolia and: 5-g" [jl]. \r\n ii. "scotland" [jl]. [a mixed gathering; central specimen and two lowest ones are d. anglica]',
#  '1 folder. rumex maritimus [ta]. i. "rumex maritimus" jl. \r\n ii. "at catfield on the common, and at brundal, 5 miles from norwich in a pit near the public house. mr. w" humphry" b.',
#  'folder 1. antirrhinum spurium [ta]. "near weymouth"[jl]',
#  '1 folder. bunias cakile [g], flora scotica ed. 1, 363 (1777)',
#  'folder 1. carex panicea [ta]. cites linn. sp. pl. 1387; ray\'s syn. 418; micheli t. 32, f. 11; pluk. t. 91, f. 7; flor. dan. t. 261. "pink carex with tumid capsules. it is frequent in bogs & moist meadows. june & july" [jl]. iii. "scotland, yalden" [jl]. iv "carex panicea" [b].',
#  'anagallis monelli [ta]. [specimen consists of a single flower only.] [species occurs in southwestern europe.]',
#  '1 folder. tillaea muscosa [ta]. [specimen missing from folder.]',
#  '1 folder. campanula patula [ta]',
#  '1 folder. arundo arenaria [ta]',
#  'folder 1. carex arenaria [ta]. i. "carex arenaria spica composita, spiculis androgynis, inferioribus remotioribus foliolo longiori instructis, culmo triquetro. lin: mich: t: 33. f: 4. pluk: t: 34. f. 8. flor: pruss: t: 31" [jl].',
#  '1 folder. malva rotundifolia [ta], flora scotica ed. 1, 374 (1777).',
#  '1 folder. bromus giganteus [ta], flora scotica ed. 1, 104 (1777). i. cites linn.: huds.; ray\'s syn. 415. \r\n ii. "tall brome-grass. in woods & shady hedges. august" [jl]. \r\n iii. "bromus giganteus" [jl].',
#  '1 folder. stellaria holostea [ta]',
#  '1 folder. medicago polymorpha β [g].',
#  '1 folder. carex sylvatica ta; i. "linnaeus made this a variety of vesicaria. g7 - [g]. \r\n ii. "carex sylvatica. huds:" [jl]. \r\n iii. "c. sylvat: hud: v: c: vesicar: b lin: but i think improperly" [jl].',
#  'campanula rotundifolia [ta], i. "near perth" [jl]',
#  'folder 1. holcus lanatus lightfoot [g]. i. *holcus lanatus" [jl].',
#  'folder 1. polypodium filix foemina [g], flora scotica ed. 1, 673 (1777). i. "polyp: filix foemina. england. frequent" [jl].',
#  'plantago major b scoparia [ta]. cites ray\'s syn. 314. "besom plantain, or plaintain with spoky tufts. in the isle of thanet at reculver" [jl]. [specimen probably a fasciated form of p. major. ]',
#  'folder 1. scabiosa arvensis [?], flora scotica ed. 1, 114 (1777). i. "gad\'s hill (3 miles southeast of gravesend in kent), hoary variety" [jl].',
#  'folder 1. cucubalus baccifer [g]. i. "bulstrode" [jl]',
#  'folder 1. sanguisorba officinalis d (westmoreland) [ta]. i. "i suspect this to be either the sanguisorba media or canadensis. i found it near orton in westmoreland near six feet high. be pleas\'d to return it, for i have no more, & if it be a variety it is a most remarkable one." (on reverse:) "this is the sanguisorba off. major, and is common in all the moist meadows of westmoreland where it is rarely less than 3 foot high" [?].',
#  '1 folder. pisum sativum b ta.',
#  'folder 1. lycopodium selago.\r\ni. cites linn. \r\n ii. anglis. firr clubmoss. on the tops of the highest mountains in the north of england, & wales. it has also been found on hilly places in the south, as on the heaths between godalmin [godalming near guildford in surrey] & wakehurst in sussex, & on shotover hill near oxford [jl].',
#  '1 folder. galium montanum [g]. i. *galium... [illegible] in a gravel pit pond on hounslow heath towards twickenham, middlesex seed red subscabra" [jl]. [specimens marked "x" are probably g. palustre.] [range of this species in britain is now (1975) devon, hants, channel isles and probably southeastern yorks (vc 61).]',
#  'folder 1. chenopodium rubrum ta. i. "horton common. leaves shining on both sides" jl.',
#  'folder 1. matricaria parthenium.',
#  'genista pilosa l.\r\ni. "genista pilosa lin: near culford & lachford in suffolk" [jl]',
#  'bromus erectus [ta]. i. cites huds. \r\n ii. "upright bromegrass. in dry & chalky pastures, but not common. june" [jl].',
#  '1 folder. trifolium subterranean [ta].',
#  '1 folder. caltha palustris ta. i. "caltha palustris" jl.',
#  '1 folder. lythrum salicaria ta. i. "lythrum salicaria lin: purple spiked willow-herb. anglis" [jl].',
#  'dianthus armeria [ta]',
#  'folder 1. campanula trachelium [ta]',
#  '1 folder. arenaria tenuifolia [ta], flora scotica ed. 1, 1102 (1777). i. "arenaria tenuifolia 10- and: 3-g" [jl]',
#  'zostera marina jl.',
#  'folder 1. littorella lacustris [ta], flora scotica ed. 1, 571, 1129 (1777). "wales. lakes" [jl]. "plantago uniflora. teesdale" [jl].',
#  'folder 1. vicia lutea [g]. "vicia lutea. the common kind is large, ramping, the stalks a yard long. the leaves in each have 4, 5 & 6 pair of pinnae, but in this kind are scattered over with a few stragling hairs. the stipulae slightly semisaggitate & are on the under side of a black red colour. the flowers are of a greenish yellow streak\'d w* green veins. the pods are pendulous, rough & hairy, containing 6 or 7 seeds. the cirrhi are more curl\'d & twisted. the other variety has stalks only from 6 to 12 inches long. leaves & the whole plant entirely smooth. stipulae green on both sides. flowers\' similar but more whitish, & reddish & the unguis of the vexillum on the back; the pods entirely smooth" [jl].',
#  '1 folder. rosa canina var. dumalis sensu wolleydod "lady stamford\'s rose from cheshire, wild. a red flower, & smooth round or subconic. german. an nova?" [jl].',
#  'folder 1. atriplex patula l.\r\n"this i think from pembrokeshire coast" [jl]',
#  'folder 1. chenopodium album l.\r\ni. "chen: album. certe. cowley field" [jl]\r\nii. "chenop: album. cowley field [near uxbridge in middlesex], large" [jl]',
#  'folder 1. filago gallica [ta].',
#  '1 folder. carex tomentosa ta; lightfoot, c. filiformis linn. & linn. trans. v.2. g. [g]. i. "carex (tomentosa) spicis femineis subpefoot dunculatis erectis, capsulis subglobosis tomentosis. syst. nat. 617. mantiss. (p. 123). it agrees with the description & fig: of scheuchzer. gram. p. 425. tab. 10 f. 11. which is the synonym of carex filiformis lin. but that author having taken no notice of any hairy capsules in the specific difference of his c. filiformis, & yet made that circumstance the principal characteristic of c. tomentosa, i conclude these specimens to belong to his c. tomentosa" [jl]. \r\n ii. "carex tomentosa. lin: syst. nat." [jl].',
#  '1 folder. anemone nemorosa ta.',
#  '1 folder. eriocaulon decangulare [ta], flora scotica ed. 1, 569 (1777). "gathered some august 31* others the 16* of september." [jl]',
#  'folder 1: triglochin maritimum [ta]: i. "triglochin maritima: yalden" [jl]',
#  'folder 1. melittis melissophyllum [ta]. i. cites ray\'s syn. 242. "bastard balm. june & july. this is found in the woods about totness in devonshire, haverford-west in pembrokeshire, and about net catalley abbey in hampshire by st w musgrave" [jl].',
#  '1 folder. aquilegia vulgaris ta.',
#  'folder 1. actaea spicata ta. i. * actaea spicata" jl.',
#  '1 folder. potentilla alba [ta]. i. "potentilla alba. kew. may & april" [jl]. [species occurs in central and southern europe; probably cultivated at kew.]',
#  'geranium moschatum [ta], flora scotica ed. 1, 1136 (1777).',
#  '1 folder. sison amomum [ta]',
#  '1 folder. colchicum autumnale l.',
#  '1 folder. geum rivale [ta].',
#  '1 folder. ribes rubra [ta]; ribes alpinum [g]',
#  'folder 1. poa annua [ta]. i. cites linn.; ray\'s syn. 408. \r\n ii. *annual meadow-grass, or suffolk grass. this is found elsewhere in pastures, | & by path-sides, flow\'ring the greatest part of the year. it is an excellent grass for the dairy. see stillingfleet\'s account & figure of it in his tracts" [jl].  \r\n iii. "poa annua" [jl].',
#  '1 folder. rumex acetosilla [ta]. i. "scotland. yalden" jl.',
#  '1 folder. lychnis viscaria [ta]. i. "lychnis viscaria lin: on the rocks in edinburgh park. scotland" [jl].',
#  '1 folder, carduus acaulis [ta], flora scotica ed. 1, 458 (1777).',
#  '1 folder poterium sanguisorba l. "poterium sanguisorba" [jl]. cites ray\'s syn. 203. "common burnet. june. it is frequent on dry & chalky pastures. it is esteemed a powerful astringent, but is neglected in the present practice. it has also been lately recommended as an excellent & very profitable fodder for cattle, but several gentlemen who have made experiments for that purpose affirm that it does not answer the encomiums bestow\'d upon it" [jl].',
#  'rhinathus crista galii [ta], flora scotica ed. 1, 322 (1777).',
#  '1 folder. medicago sativa ta.',
#  '1 folder. sedum acre [ta]. i. "halkam sussex" [jl].',
#  'folder 1. scilla autumnalis l.',
#  'folder 1. trifolium ornithopodioides [g]. i. "trifolium ornithopodioides. tuthill fields"[jl]',
#  '1 folder. potentilla fruticosa [ta]. i. "potentilla fruticosa. newfoundland [given by banks]" [jl]. \r\n ii. *potentilla fruticosa. bullstr: (bulstrode park]" [jl].',
#  '1 folder. cucubalus viscosus [jl]. "cucubalus viscosus. 10- and: 3g:" [jl]. "this does not agree with the linnaean specimen, which bears a spike of flowers with short peduncles, & the upper leaves of the stalks are cordate & sessile" [jl]',
#  'juncus acutus d ta. i. "juncus acutus var:y certainly. mr. banks common every where" jl. \r\n ii. "juncus acutus isle of purbeck near brawnsey [brownsea island in poole bay, dorset]. it seems to bea strange variety (if so) of j. acutus" [jl].',
#  '1 folder. nymphaea alba [g]',
#  'folder 1. saxifraga nivalis [ta]. i. "saxifraga nivalis lin: snowdon in wales, & on the mountains of breadalbane in scotland" [jl]. \r\n ii cites linn. vid. fl. lap. t. 2, f. 5, 6; ray\'s syn. 354, t. 16, f£. 1.  \r\n iii. "mountain saxifrage. this rare plant is found on the highest rocks of snowdon in carnarvonshire, & no account of it anywhere else in great britain. it flowers in june. we have seen it in scotland, on the mountains of breadalbane" [jl]; *in ben weevish east ross scotland, t. agnew. also in craig chailleach breadalbane scotland. t.a" [ta].',
#  'folder 1. geranium cicutorium "var. bimaculata [g], flora scotica ed. 1, 366 (1777). "geranium from norfolk with two dots on the two uppermost petals. bustrode [bulstrode]" [jl].',
#  'folder 1. bromus pinnatus [g]. i. "weymouth road sides" [jl].',
#  '1 folder. veronica triphyllos [ta]. i. "veronica triphyllos grows most abundantly on the sandy soil 2 or 3 miles south of doncaster" (f); "mr. frankland" [jl]. \r\n ii. *veronica triphyllos* [jl]. page 179',
#  '1 folder. centaurea solstitialis [ta]. "centaurea solstitialis. kew. july & aug: anglia" [jl].',
#  'folder 1. cardamine petraea [ta], flora scotica ed. 1, 347 (1777). i. "scotland" [jl]',
#  'folder 1. convallaria multiflora l.',
#  'folder 1. lactuca saligna [ta].\r\n \r\n ii. *pancras w* mr banks" [jl].',
#  'folder 1. lactuca scariola [g].\r\ni. "pancras w* mr banks. l. scariola" [jl].',
#  'folder 1. artemisia coerulescens [ta]; a. maritima [g]. i. "near mersey" [jl]',
#  '1 folder. sedum rupestre [ta]. i. "bristol & chepstow" [jl].',
#  'salix vitellina [ta]. "salix vitellina. mas. in the osier *- bed by mr. biggs\'s mill [near cow- \'ley, middlesex]. april 29th. 1777. a cold season. it is diandrous" [jl].',
#  'sheet 1. saxifraga stellaris [jl]. i. cites linn. sp. pl. 400; ray\'s syn. \r\n ii. "hairy kidney-wort. i gathered this at buckbarrow-well in longsleddale (long sleddale in the valley of the river sprint) about ten miles from kendal in westmoreland, the place mentioned by ray. june to ufoot september" [jl].  \r\n iii. "snowdon"[jl]  \r\n iv. "saxifraga stellularis. ben lomond. mr. y. [thomas yalden] says he found the s. nivalis there" [jl]. \r\n  [thin sheet attached to sheet 1 probably nothing to do with herb. lightfoot.]',
#  'folder 1. saxifraga oppositifolia [ta]. i. cites linn. sp. pl. 402; ray\'s syn.  \r\n ii. "mountain heathlike sengreen, with large purple flowers. march & april. i found this upon the rocks near the summit of the west-side of ingleborough hill in yorkshire. it grows likewise in wales upon the rocks of snowdon" [jl].',
#  '1 folder. myagrum sativum [ta], flora scotica ed. 1, 336 (1777). i. "myagrum sativum. these are the best i have" [p]; "by mr. pitchford" [jl].  \r\n ii, "myagrum sativum. gold of pleasure. kew. aug! anglia" [jl]',
#  '1 folder. asplenium ceterach [ta]',
#  'folder 1. leontodon hispidum [ta]; l. autumnale [g].\r\ni. "hounslow heath, gravelly soil. october: leontodon hispidum w* smooth calyx" [jl].',
#  'folder 1. carex paniculata [ta]. i. cites ray\'s syn. 422; moris. hist. ox. sect. 8, t. 12. £ 23; micheli, t. 33, f£. 7. \r\n ii. "panicled carex. june & july. this is found in bogs & watery places, but not very common [jl]; "in great plenty at virginia water. g." [g]. \r\n iii. "carex paniculata" [jl]. \r\n iv. "carex paniculata"',
#  '1 folder. ruppia maritima [ta]. i. "scotland. invernesshire" [jl]',
#  'folder 1. cistus helianthemum [ta, flora scotica ed. 1, 281(1777). "cistus helianthemum var. petalis basi fulvis, ex horto bullstrodiensi" [jl]',
#  'lamium purpureum [ta]',
#  '1 folder. lactuca virosa [ta].\r\n[specimen incomplete.] ©',
#  'draba muralis [ta].',
#  '1 folder. trifolium arvense ta.',
#  'folder 1. juncus sylvaticus [ta], flora scotica ed. 1, 186, 1120 (1777). i. "juncus sylvaticus l. gramen nemorosum hirsutum latifol: maximum. ray. great hairy wood r: [wood rush] clement\'s gard:" [jl].',
#  '1 folder linum perenne l: f: [ta].\r\n"sibirian flax. july. this plant is vastly taller than our english kind, & much more branched, but has scarcely any specific distinction & is probably no other than a cultivated variety. it is in many of our curious gardens" [jl].',
#  'folder 1. melampyrum pratense [ta]; huds. [g]; m. sylvaticum linn. [g]. i. "melampyrum sylvaticum lin: on the road side going from taymouth, the seat of l. breadalbane [lord breadalbane] in scotland, to the hermitage. july 1775" [jl].',
#  'folder 1. juncus filliformis ta. i.\r\njuncus filiformis lin: e suecia accepi a d. hyde" jl.',
#  'sheet 1. ophrys corallorhiza [jl]. flora scotica ed. 1, t. xxiii, 523 (1777). i. "ophrys corallorhiza lin: in the woods above little loch-broom in ross-shire. scotland" [jl]',
#  '1 sheet. thlaspi perfoliata [ta]',
#  '1 folder. cynosurus coeruleus [ta], flora scotica ed. 1, 100, 1115 (1777). i. cites linn. sp. pl.; ray\'s syn. 399. \r\n ii. "blue dog\'s tail grass. may. this grows upon the rocks near seattle in yorkshire, & on the sides of ingleborough hill; and other the like places in westmoreland; and on the sides of the highland mountains in scotland" [jl]. \r\n iii. "cynosurus caeruleus" [jl]. [specimens are subsp. calcare (celak.) hegi].',
#  'folder 1. cerastium latifolium [g]. i. cites ray\'s syn. 349. \r\n ii. "cerastium alpinum. this was gathered upon snowdon at the top of the highest rock call\'d clogwyn y garnedh. june" [jl]. \r\n iii. "top of snowdon" [jl].',
#  'folder 1. carex distans [ta]. i. "carex distans" [jl].',
#  'folder 1. polygonum minus [ta]. i. "polygonum minus at sheer near aldbury [now shere near albury] in surrey" jl. \r\n ii. "polygonum minus. tothill fields m* hudson. this seems to be a hybridous plant between hydropiper & persicaria maculosa it is however always patulous & reclining" jl.',
#  'folder 1. sisymbrium irio [ta]. i. "sisymbrium irio oxford" [jl]\r\n[loose label]. \r\n ii. "sisymbrium irio at wisbech in the isle of ely, but sparingly" [pitchford]; *m* john pitchford" [b]; "by m* bryant"[jl]',
#  '1 folder. bryonia alba [ta]',
#  'folder 1. pyrola secunda [g], flora scotica ed. 1, 219 (1777). "dented-leaved winter-green. june. this is said to be found in haselwood near s\' walter vavasor\'s park in yorkshire. these specimens came, one from sweden, the other from newfoundland. i have found it also in scotland in shady old beech woods. n.b. the antherae in this species stand out of the corolla, and the stigma is lengthened beyond the stamina" [jl]. "pyrola secunda lin: from newfoundland & scotland" [jl]. cites ray\'s syn. 363; fl. danica t. 402. "this is said to be found in haslewood... in yorkshire. these specimens were gathered in newfoundland by joseph banks esq\'. n.b. the only material difference between this species & the pyr: minor consists in the extrusion of the stamina & style. the flowers lean also to one side of the stalk, & the leaves are more acute" [jl].',
#  'carduus crispus [ta]. i. "this seems to resemble, if it be not the same, as the c. acanthoides lin: according to the specimens in his hort: sicc: the c. crispus of lin: has broad jagged leaves, hoary underneath, & heads like this, or our crispus. in anglia, non inveni" [jl]',
#  'folder 1. cistus marifolius lin. \r\n ii. hoary dwarf mountain cistus, with yellow flowers. july. ray relates this plant to have been found on some rocks near kendal in westmorland by m* newton; also at buck-barrow bank scar, between brigsteer and coniston, & on the rocks at cartmel-wells in lancashire plentifully. it was sent from the physic garden in oxford to the princess dowager\'s garden at kew, from whence i receiv\'d it [jl]. \r\n iii. "cistus marifolius lin. ex. horto kewensis" [jl].',
#  '1 folder. festuca loliacea [g]. "caversham [near reading in berkshire]" [jl]. \r\n ii. "festuca- caversham hills, june" [jl].',
#  '1 folder. cineraria integrifolia [ta]; c. alpina huds. [g]. i. cites ray\'s syn. 178. \r\n ii. "mountain ragwort. june. on gogmagog hills & newmarket heath" [jl].',
#  'folder 1. typha angustifolia [g]. i. cites ray\'s syn. 436. \r\n ii. "narrow-leaved cats-tail. july. this is found in ditches & ponds, but not frequent. - i gathered these specimens in a ditch not a mile from oxford, by the road side going towards dorchester" [jl]',
#  '1 folder. scleranthus annuus? [ta].',
#  '1 folder. avena fatua [ta]. i. cites lin.; ray\'s syn. 389. \r\n ii. "bearded wild oats or haver. it is frequent among corn. july. the beard of this oat makes a very sensible hygrometer" [jl]. \r\n iii. "avena fatua from m\' pitchford. it has generally but 2 flowers in a spicula" [jl]. \r\n iv. "avena fatua" [tl].',
#  'folder 1. allium arenarium [ta]. i. "allium arenarium"',
#  '1 folder. potamogeton compressum [ta]. [same folder as for p. acutifolius; see jl label there.]',
#  'folder 1. salix viminalis [g].',
#  '1 folder. poa trivialis-stipula interfoliacea. longa [g]. i. cites linn.; ray\'s syn. 409; moris. hist. ox. sect. 8, t. 5, f 18. \r\n ii. "great meadow grass. june. in meadows & pastures frequent. the flowers of this are all smooth at the base, having no kind of pubescency; and the leaves and stalks are a little rough to the touch. these are the chief marks to distinguish it from the poa trivialis, the number of flowers in each spicula being very uncertain in both kinds; & indeed the above characters do not seem sufficiently constant to constitute two different species. see gmelin: flor: sibiric: vol. 1. p. 102, 103"',
#  'folder 1. arabis turrita [ta]. i. "arabis turrita, near oxford" [jl]. [also on this folder is a pencil sketch of an arabis species, probably by jl; see under arabis sp.]',
#  'folder 1. artemisia campestris [ta]. i. "artemisia campestris elden" [jl]',
#  '1 folder. arenaria trinervia [ta].',
#  'folder 1. gnaphalium sylvaticum huds. and g. rectum [g] i. *gnaphalium anglicum" [jl].',
#  '1 folder. schoenus mariscus ta. i. cites ray\'s syn. 426; moris. hist.. sect. 8, t. 11, f. 24. \r\n ii. "longrooted bastard cyperus. july. this is found on some of our bogs, but not common. it grows plentifully on hinton-moor near cambridge"[g]',
#  "lycopodium annotinum.\r\ni. cites linn.; ray's syn. 107; dill. musc. t. 69, f. 9. \r\n ii. welch club-moss. july & aug. this rare species was found in carnarvon-catal:shire upon the mountain call'd rhiwr glyder above the lake lhyn y cwn [jl].",
#  '1 folder. leontodon autumnale [ta].\r\ni. "if this be not a variety of the leontodon autumnale, i do not know what it is-it grows in sandy ground" [b]; "it is undoubtedly so" [jl].',
#  '1 folder potamogeton pusillum [ta]. i. "pot: pusillum. it agrees well with loesel. & vaillant\'s figures. there can be no doubt. percy lodge [near colnbrook]. pond & c^ [jl]. \r\n ii. "potamg. pusillum. percy lodge" [jl]. [specimen entwined with material of p inchoides.]',
#  'folder 1. euphorbia platyphyllos\r\ng. i. "euphorbia platyphyllos lin: ex horto kewensi" jl.  \r\n ii. "euphorbia platyphyllos certainly. kew garden" jl.',
#  'folder 1. trifolium scabrum [ta]. i. "trif: scabrum for certain. it agrees w the specimens in buddle. hort. sicc. but are very small"[jl]',
#  '1 folder. chrysanthemum inodorum [ta]; c. leucanthemum [g].',
#  'scrophularia aquatica [ta]. i. *m\' holkham. an scr: ; aquat: s: mellissphyll?" [jl].',
#  'vicia hybrida [ta]; v. sepium [g].',
#  '1 folder. hieracium paludos: westmoreland" [jl], flora scotica ed. 1, 438 (1777).',
#  'folder 1. schoenus albus [ta], flora scotica ed. 1, 87 (1777). i. cites linn. sp. pl. 65; ray\'s syn. 427, \r\n ii. "white-flowered schoenus or rush-grass. in bogs, as at virginy water [virginia water near bagshot in surrey] between egham & bagshot, & in a bog between west wickham & croydon in. surrey. july" [jl]. tm- "schoenus albus" [jl].',
#  'folder 1. polypodium cristatum [g].\r\n"polyp: cristatum lin:" [jl]',
#  '1 folder. polypodium cristatum var. [g]. i. *polyp: cristatum a variety wt tripinnate & pinnatifid leaves from scotland. i think near corry in arran" [jl].',
#  'folder 1. chenopod: hybridum [ta]',
#  'carlina vulgaris [ta]',
#  '1 folder. adonis autumnalis ta.',
# ...
#  '. folder 1. carex caespitosa [ta], flora scotica ed. 1, 560 (1777). l "carex acuta y?" [pitchford]; "c. recurva huds. this seems to be the plant which hudson now calls c. caespitosa which was before understood as a variety y of c- acuta; but i verily believe it to be a distinct catal species. c. caespitosa of dr good-- gh. by m\' pitchford" [jl]. \r\n ii. "carex caespitosa" [b]. \r\n iii. "carex caespitosa. spicis omnibus masculis" [b].',
#  '1 folder. viburnum opulus l.',
#  'folder 1. bartsia viscosa [g], flora scotica ed. 1, t. xiv, 321, 1126 (1777). i. cites ray\'s syn. 285. \r\n ii. "marsh eye-bright cow-wheat. this grows in boggy grounds in the west of england, in dorsetshire, devonshire &, cornwall" [jl]. \r\n iii. "bartsia viscosa lin:" [jl]..',
#  'sisymbrium sophia [ta], flora scotica ed. 1, 354 (1777). [a fragment only.]',
#  'folder 1. lycopodium selaginoides (flora scotica ed. 1, 686 (1777)). "i would like you to mention the place of growth" [jl]',
#  'folder 1. cerastium alpinum [g]. i. "anglesey. cerastium alpinum. q: an var: aut nova species? fig: cerast: alp: non quadrat: flor: dan: the fig: in the fl. dan: of cerast: alpinum agrees with this, only taller & more branched, bearing 6 flowers, capsulis oblongis. in the fl. lapponic: lin: says this plant commonly produced 1 or 2 flowers when wild" [jl]. \r\n ii. "cerastium alpinum? newfoundland. the flor: dan: agrees well with the tall one. i believe the others to be nothing but varieties" [jl]. [only two specimens in folder; on left c. arcticum, probably the plant from anglesey; on right c. arvense, maybe the specimen from newfoundland collected by joseph banks. ]',
#  'folder 1. salsola fruticosa ta. i. "windmill point near pool" jl.',
#  '1 folder. rubus idaeus l.',
#  'folder 1. gnaphalium margaritaceum [g]. "gnaphalium armeria s? to \'ghtfoot be british. bulls: [bulstrode park]"',
#  '1 folder. sonchus arvensis. varieties',
#  '1 folder. chaerophyllum temulentum [ta]',
#  'ajuga reptans pt.',
#  '1 folder. aira setacea hud. [ta]. "aira setacea huds. aira foliis setaceis, panicula secunda, ramosa, nutante, aristis flosculis duplo longioribus, recurvis. this is certainly the plant intended by huds. but very badly described both as to habit & place of growth. i found it on cawston decoy, 12 miles north of norwich, in a very deep rotten soil. its leaves were scarce visible, being intirely immersed in water. our idea of the aira setacea huds. was that it must be a very small plant, growing on a very dry barren soil; for such is the nature of stratton heath in general. there are indeed some rotton boggy places also upon it, of the same nature with cawston decoy; but we should never have thought of searching for it, unless we have been particularly directed to do so. i make no doubt but this plant may now be found, not only on stratton heath; but in many other parts of the kingdom, by those who are qualified to look after it and have hardiness enough to tread the bogs in proper season. [on reverse] collected all that i found of it, were only nine specimens, two of which catalo want the bottom leaves, they being intirely out of my reach. i have sent you four compleat ones, and beg you would give one of them to m\' banks." [b]; "rev mr bryant" [jl] [four specimens are present, so it appears that lightfoot did not pass one on to joseph banks as bryant requested]. "aira setacea, huds. found on cawston decoy, 12 miles north of norwich. july 12^ 1776" [b].',
#  'folder 1. epilobium alpinum [ta], flora scotica ed. 1, t. 199, 1122 (1777). "epilobium alpinum lin: from ben-lomond in scotland" [jl]. \r\n ii. "from loch-broom mountains in ross-shire scotland" [jl].',
#  'folder 1. potamogeton [ta]; p. marinum [g]. i. "potamogeton marinum. mr. crow norfolk" [jl]. \r\n ii. "the same with mr. crowe\'s p: marinum. sent by him at the same time" [jl]. \r\n iii. "i imagine this to be evidently that of ray pag: 150. n* 13 w? is hudson\'s syn: for p: marinum. but from description i take the plant to be p: pectinatum lin:[jl]',
#  'anthyllis vulneraria l.\r\ni. "anthyllis vulneraria frequent in norfolk" [b]; "bryant" [jl]',
#  'folder 1, statice limonium [ta]. i. "statice limonium" [jl].',
#  '1 folder. rumex crispus [ta]. i. "rumex crispus, valvulis integris graniferis, foliis lanceolatis undulatis acutis ubique" jl.',
#  '1 folder. cucubalus viscosus [ta]; cucubalus otites [g]',
#  'folder 1. holcus mollis [ta]; - lightfoot [g]. i. cites linn.; ray\'s syn. 404.  \r\n ii. "creeping soft-grass. in corn-fields. june & july" [jl].',
#  'sheet 1. cistus guttatus [g]. "isle of anglesey, llanfair opposite the skerries" [? ta]',
#  'folder 1. salix fragilis [g]. "i take this to be salix amygdalina. lalam [now - spelled laleham] | near staines" [jl].',
#  'folder 1. convallaria polygonatum l.',
#  '1 folder. polypodium aculeatum [?]; p. lobatum huds. [g]. i. "england" [jl]',
#  '1 folder. polygonum hydropiper ta. i. "polygonum hydropiper"[jl]',
#  '1 folder. hippophae rhamnoides [ta]. i. "hippophae rhamnoides. by the sea side near sandwich and near sandown castle in kent" [jl].',
#  'folder 1. euphorbia portlandica ta. i. "exmouth in devonshire." euphorbia portlandica lin:" jl.',
#  '1 folder, carduus eriophorus [ta], flora scotica ed. 1, 455 (1777).',
#  'folder 1. scirpus maritimus [ta].\r\ni. cites linn. sp. pl. 74; ray\'s syn. 425. \r\n ii. "round-rooted bastard cyperus. by the ditch-sides in salt marshes in abundance. july & august" [jl]. \r\n iii. "scirpus maritimus" [jl].',
#  'folder 1. brassica rapa [ta].',
#  'folder 1. mentha arvensis [ta]. i. "langley or iver heath" [jl].',
#  'folder 1. melampyrum arvense [ta]. "melampyrum arvense found eight miles before you come to norwich between that & thetford among bushes, by s\' in* callum [sir inigo cullum, a relative of sir john cullum of bury st. edmunds]" [jl]',
#  'folder 1. hypericum humifusum [g]',
#  '1 folder. carex incurva [ta], flora scotica ed. 1, t. xxiv, 544 (1777). 1. "carex from isle of arran by d h. [john hope]"[jl] [specimen 15 the type of c. incurva lightfoot and the basis for the corresponding plate in flora scotica.]',
#  'folder 1. juncus campestris [ta], flora scotica ed. 1, 186 (1777).',
#  'folder 1. salix alba [g]. "salix alba. furnace at newent [in the forest of dean, gloucestershire, :jus birthplace]. common white willow. it grows to a large tree. right" [jl].',
#  'folder 1. orobus sylvaticus [ta], flora scotica ed. 1, t. 390, 1129 (1777). "rum" [jl]. \r\n ii. "clyde, scotland" [jl].',
#  'folder iris xiphium [g]; tris pseudacorus?, xiphium mihi. t.a. [ta]',
#  'folder 1. rosa villosa l.',
#  'folder 1. ornithogalum luteum l.',
#  'samolus valerandi [ta]. i. "samolus valerandi. frequent in norfolk" [b]; *m* bryant" [il].',
#  '1 folder. ulmus campestris [ta], flora scotica ed. 1, 151, 1094 (1777). i. "common elm" [jl]',
#  '1 folder. scandix odorata [ta], flora scotica ed. 1, 166, 1118 (1777)',
#  '1 folder. polycarponm tetraphyllum [ta]. i. "polycarpon tetraphyllum lin: 3- and: 3-gyn: in portland island dorsetshire. july & aug."[jl]',
#  'folder 1. juncus [ta]. i. "by mr. banks. newfoundland" [jl].',
#  '1 folder. carduus heterophyllus [ta], flora scotica ed 1, 455 (1777); lightfoot [g]; c. pratensis huds. [g]. "english soft or gentle thistle. on the borders of bogs in heathy places. by the side of the duke of marlborough\'s pond in the black park near langley, bucks. and on the border of a bog on hounslow heath between twickenham & hampton. june" [jl].',
#  'veronica scutellata [ta]. i. "veronica scutellata" [jl].',
#  'folder 1. myosurus minimus ta.',
#  'folder 1. avena sativa [ta]. i. cites lin.; ray\'s syn. 389. \r\n ii. "white oats. this is sown in most parts of england. july" [jl]. [mixed, with a. sativa marked e',
#  '1 folder, conyza squarrosa [ta], flora scotica ed. 1, 473 (1777).',
#  'folder 1. lathyrus sylvestris [g]\r\ni. cites linn., sp. pl. ed. 1: 733 (1753); ray\'s syn. \r\n ii. "marsh chickling vetch. july & aug: upon the bogs in charley forest, near bardon hill, leicestershire. this was found upon some bogs in lincolnshire" [jl]',
#  '[specimen on left is l. binervosum.]',
#  'folders 1 and 2. inula crithmoides [ta].',
#  'folder 1. pastinaca sylvestris [ta]',
#  'folder 1. eriophorum vaginatum right foot [ta]. i. cites linn. sp. pl. 76; ray\'s syn. 436; moris. hist. sect.\'8, t. 9, f. 6. \r\n ii. "eriophorum vaginatum" [jl]. \r\n iii. "scotland, yalden" [jl]. \r\n iv. "hair\'s-tail rush. this is found upon the moors in the north of england pretty frequent, but is very rare in the southern counties. i gathered these samples in the bogs between croydon & west wickham in surrey. it appears in this flowering state in the end of april" [jl].',
#  'lathyrus hirsutus [ta]\r\ni. "lathyrus hirsutus near mundenhall 5 miles from maldon in essex" [jl] \r\n ii. "lathyrus hirsitus. an english plant about rochford in essex. clement\'s" [jl]',
#  'folder 1. ranunculus repens ta. i. "ranunculus repens" jl.',
#  '1 folder. galanthus nivalis ta.',
#  'cochlearia groenlandica [ta]. i. *c. groenlandica. bulls: gard: [bulstrode park garden] cl; fficinalis l',
#  'folder 1. aegilops incurvata [ta]. i. cites linn.; ray\'s syn. 395, \r\n ii. "sea darnel grass or hard-grass. july. in the sea marshes, at sandown castle in the isle of thanet, & many other places" [jl].',
#  'folder 1. juncus inflexus ta; j. glaucus g. i. "junc: inflex: holkam cambridge" jl.',
#  'folder 1. acrostichum ilvense [ta]. i. cites linn.; ray\'s syn. 118. \r\n ii. "hairy fern with red-rattle leaves. this very rare fern is said to have been found on a moist black rock almost at the top of clogwyn y garnedh, facing north-west, on mount snowdon, by dr. richardson & mr. lhwych; but it has not been found there lately though many researches have been made for it. it throws out many leaves from one root, the young ones of which are curl\'d & very hairy. the leaf here exhibited came from linnaeus in sweden, & was one of the largest that grew from the same root" [jl]. \r\n iii. "acrostichum ilvense. \'this very specimen was gathered upon snowdon & given to me by mr. dickson" [jl]".',
#  'folder 1. dentaria bulbifera [g].',
#  'folder 1. draba incana [ta]. i. "draba incana. newfoundland. mr. banks" [jl].',
#  'folder 1. cheiranthus 3-cuspidatus [g]. [specimen not m. tricuspidata (l.) r.br]',
#  'folder 1. pimpinella major [g]. i. "between deal and dover 2 miles from dover" [?]',
#  'folder 1. rubus caesius l.',
#  'folder 1. geranium phaeam [ta]. i. "geranium phaeum" [jl].',
#  '1 folder. butomus umbellatus [ta]',
#  '1 folder. carex digitata [ta]; g. [g]. i. "carex digitata lin: found near bath by mr sole [william sole] of that place" [jl]. \r\n ii. "carex digitata for the rev? mr. lightfoot" [sole]; "from mr. sole" [jl].',
#  '1 folder, aira praecox [ta]. i. cites lin.; ray\'s syn. 407, tab. 22, \'fig. 2; pluk. alm. t. 33, f. 9. \r\n ii. "early hair-grass. this grows on sandy heaths, & barren places not unfrequent, flowering early in may" [jl]. \r\n iii, "aira praecox" [jl].',
#  'folder 1. hordeum sylvaticum [ta]. i. "hordeum sylvaticum-a new species. gramen secalinum majus sylvaticum. r. syn: p. 392" jt.. 07',
#  'folder 1. orchis bifolia [ta]. [no flowers.]',
#  'folder 1. ophris monorchis [ta]. i. cites ray\'s syn. 378. \r\n ii. "the yellow musk orchis. i gathered these specimens on the sides of the calk hills by cawsham near reading. i have seen it likewise in some old chalk pits at bulstrode near beaconsfield, bucks. it is in full flower about the end of june" - uy.',
#  'folder 1. antirrhinum repens [g]. i. "cites dillenius, hortus eltham., t. 163, f. 197. \r\n ii, "upon the chalk hill going down to henley upon thames from london, and in some chalky places near peppard 3 miles from henly. july" [jl]',
#  'folders 1 and 2. inula helenum [ta].',
#  'genista anglica [ta]',
#  'folder 1. carex elongata lin.?\r\n[ta]; c. divulsa linn. trans. g.\r\n[g]; c. canescens huds. [g]. i\r\ncites micheli t. 33, f. 11 and ray\'s\r\nsyn. 424. \r\n ii. "this is commonly\r\ncalled by our english botanists c.\r\ncanescens, but very falsely. the\r\nmistake has been occasioned by the\r\nmis-placing of the above synonym\r\nof m\' ray" [jl]. \r\n iii. "carex canescens. spicis distantibus" [b]; "this\r\nis certainly that 424 no. 10 of ray.\r\nbut i cant think it c. [deleted]\r\nlin:" [jl]; *elongata" [ta]. \r\n iii\r\n*dr goodenough supposes this to\r\nbe the c: elongata lin: it is also\r\nthe c. canescens huds." [jl].',
#  'folder 1. carex leporina huds., carex ovalis linn. flora scotica ed. 1, 547 (1777) c. ovalis linn. trans. vol.2. g [g]. "carex leporina" [b]. \r\n ii. "carex leporina var perhaps this may be the c. divisa huds." [b]; "it is c. leporina" [jl].',
#  'folder 1. raphanus raphanistrum [g].',
#  'folder 1. mercurialis annua. [g]. i. "dorchester" [jl].',
#  'folder 1. ceratophyllum demersum ta. "ceratophyll: hounslow heath river" jl.',
#  'folder 1. \'turritis hirsuta [ta], flora scotica ed. 1, 358 (1777). i. "i must beg leave, my 80 friend, to retract what i mentioned to you concerning the plant i picked up in gloucestershire, for on inspection, i perceived my mistake. i likewise examined d\' randolph\'s specimens of cardamine bellidifolia & found them all turritis hirsuta, tho\' he said dr dillenius gave him one of the specimens i saw- he has closed a specimen of the plant collected which you will easily know-as it is our election week all the fellows are up, so that i have scarce time to say how much i am obliged by the curious specimens mr. woods brought that i am & always shall be yr. affectionate friend & serv. w. sheffield [keeper of the museum at oxford]. are you got thro\' the syngenescallass? worcoll. [presumably worcester college, oxford] friday afternoon" [sheffield]...',
#  '1 folder. lonicera periclymenum l.',
#  'folder 1. rhodiola rosea [ta], flora scotica ed. 1, 619 (1777).',
#  '1 folder. epilobium angustifolium [ta], flora scotica ed. 1, 197, 1121 (1777). "epilobium angustifolium. grays near henley, oxfordshire" [jl].',
#  '1 folder. acer campestre l.',
#  'folder 1. galeopsis hirta [ta]. i. "galeopsis hirta. solandri. sideritis arvensis latifolia hirsuta lutea. ray. syn. 242. in corn fields near bangor in carnarvonshire, going from thence towards snowdon" [jl]',
#  'folder 1. galium palustre [g]. i. "in a bog with the acrostichum thelypteris, near abingdon" [jl].',
#  'folder 1. salix fragilis [ta]; s. amygdaloides huds. [gj]; s. triandra huds.? [g]. i. "i take this to be salix fragilis rather than salix hastata. lalelam [laleham near staines]"',
#  "folder 1. sparganium natans and s. minimum [ta], flora scotica ed. 1, 540 (1777). i. cites ray's syn. p. 437 [ta].",
#  '1 folder. anthericum ossifragum huds.',
#  'folder 1. salicornia herbacea ta, flora scotica ed. 1, 69 (1777). i. "salicornia herbacea. lin: s. europaea. huds." jl.',
#  '1 folder. stellaria nemorum [ta]',
#  'folder 2. alchemilla vulgaris b minor [ta]. i. "a. minor. yalden" [jl]. \r\n ii. "alchemilla vulgaris. in an old piece of pasture behind m* bulwer\'s house, heydon [in norfolk]. the minor i never saw; i will thank you for a good specimen of it. the alpina is in my garden": [b]. [specimen in top right corner is a. xanthochlora.]',
#  'antirrhinum minus [ta].',
#  'folder 1. oxalis acetosella [ta]',
#  'triglochin palustre [ta]',
#  'gleoma hederacea [ta]',
#  '1 folder. cherleria sedoides [ta], flora scotica ed. 1, 232, 1124, 1139 (1777). i. "cherleria sedoides lin: from the isle of rum, one of the hebrides" [jl].',
#  'astragalus glycyphyllos [ta]',
#  'lepidium anglicum [ta]; lepidium petraeum [g].',
#  '1 folder. cucubalus behen [ta], flora scotica ed. 1, 226 (1777). "common behen. cawsham [near reading, berkshire]" [jl]. "ailsa craig [tiny island south of the isle of arran in the hebrides] b maritima" [jl] [refers to the righthand specimen, which is subsp. maritima]',
#  '1 folder. crocus sativus [ta]',
#  'juncus acutus ta.',
#  'folder 1. malva alcea [jl and ta]',
#  '1 folder. agrimonia eupatoria l.\r\n"agrimonia eupatoria\r\nlin: agrimony anglis. under\r\nhedges" [jl]. : ;']

# %%
from jiwer import wer, cer

# %%
wer(gold_desc, eval_desc)
# Out:
# 0.23712227121195828

# %%
cer(gold_desc, eval_desc)
# Out:
# 0.18260892485305358

# %%
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2','rougeL'], use_stemmer=True)
scores = [scorer.score(g, e)["rougeL"] for g, e in zip(gold_desc, eval_desc)]


precision = []
recall = []
f1 = []

for g, e in zip(gold_desc, eval_desc):
    score = scorer.score(g, e)["rougeL"]
    precision.append(score.precision)
    recall.append(score.recall)
    f1.append(score.fmeasure)

precision = sum(precision) / len(precision)
recall = sum(recall) / len(recall)
f1 = sum(f1) / len(f1)

# %%
print(f"Description - Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")
# Out:
# Description - Precision: 0.8995, Recall: 0.9266, F1 Score: 0.8914

# %%
print("Final Summary:")
print(f"Description - Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")
print(f"Species Name - Precision: {sp_precision:.4f}, Recall: {sp_recall:.4f}, F1 Score: {sp_f1:.4f}")
print(f"Family Name - Precision: {fam_precision:.4f}, Recall: {fam_recall:.4f}, F1 Score: {fam_f1:.4f}")
# Out:
# Final Summary:
# Description - Precision: 0.8995, Recall: 0.9266, F1 Score: 0.8914
# Species Name - Precision: 0.8751, Recall: 0.8741, F1 Score: 0.8746
# Family Name - Precision: 0.8630, Recall: 0.8630, F1 Score: 0.8630
